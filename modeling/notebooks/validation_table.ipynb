# %% [markdown]
# This notebooks generates tables with model performance metrics for different subsystems in different tests, and the average ones. In order to generate the table first the data needs to be generated. To do so run the subsystem cell in the benchmark notebook.

# %%
from pathlib import Path
import datetime
from loguru import logger
import numpy as np

from phd_visualizations.textual import generate_latex_table

from solarmed_modeling.benchmark.utils import import_benchmark_results

# %load_ext autoreload
# %autoreload 2

data_path: Path = Path("../data")
results_path: Path = Path("../results/benchmark_results.json")
eval_date_str = '20250910' # '20250829' # '20250720'

# Collect all metrics of interest
metrics_of_interest = ['r2', 'mae', 'mape']

# Latex table parameters
regular_col_ids = [
    "variable",
    # "modelling_alternative",
    "sample_time",
    "test_id",
]

regular_col_labels = [
    r"Predicted\\ variable",
    # r"Modelling\\ principle",
    r"Sample\\ time\\ (s)",
    r"Test\\ date",
]

group_row_ids = [
    "variable",
    "modelling_alternative",
    "test_id",
    "sample_time"
]

metric_info = {
    "r2": r"R$^2$\\ (-)",
    "mae": r"MAE\\ (s.u.)",
    "mape": r"MAPE\\ (\%)",
    "time": r"Time\\ (s)",
}

submetric_ids = ["val", "avg_val"]
submetric_labels = ["Test", "Avg."]
group_submetric_ids = ["avg_val"]

"""

Latex table generation expected input format:
    
    data = [
        {
            "variable": "T$_{dc,out}$ ($^\\circ$C)",
            "alternative": "Physical model",
            "time": "0.035",
            "test_id": "YYYYMMDD",
            "metrics": {
                "r2": {"T": "0.98", "V": "0.97"},
                "rmse": {"T": "0.50", "V": "0.52"},
                "mae": {"T": "0.45", "V": "0.48"},
            }
        },
        ...,
        {...}
    ]

    benchmark_output = [
        eval_date_str : {
            "system": [
                "test_id": "YYYYMMDD",
                "alternative": "",
                "metrics": {},
                "metrics_per_variable": {
                    "var": {}
                },
                "elapsed_time": ,
            ] 
        }
    ]

"""

def parse_benchmark_results_to_latex_data(
    selected_alternatives: list[str],
    selected_sample_times: list[int],
    out_var_ids: list[str],
    stats: list[dict],
    out_vars_dict: dict,
    filter_out_tests: list[str] = []
) -> list[dict]:
    table_data_total = []

    # Initialize dictionary to store lists of each metric
    for selected_alternative in selected_alternatives:
        for selected_sample_time in selected_sample_times:
            logger.info(f"Processing alternative: {selected_alternative}, sample time: {selected_sample_time} s")
            for var_id in out_var_ids:
                table_data = []
                metric_values = {metric: [] for metric in metrics_of_interest + ["time"]}
                for item in stats:
                    if item["alternative"] != selected_alternative or item["sample_rate"] != selected_sample_time:
                        continue
                    if item["test_id"] in filter_out_tests:
                        logger.warning(f"Skipping test id: {item['test_id']} as it is in the filter_out_tests list")
                        continue
                    
                    metrics_dict = {}
                    for metric_id in metrics_of_interest:
                        value = item["metrics_per_variable"][var_id].get(metric_id.upper())
                        if value is not None and np.isfinite(value):
                            metric_values[metric_id].append(value)
                            metrics_dict[metric_id] = {"val": value, "avg_val": ""}
                    # Add elapsed time to metrics_dict
                    metric_values["time"].append(item["elapsed_time"])
                    metrics_dict["time"] = {"val": item["elapsed_time"], "avg_val": ""}    
                    
                    table_data.append(
                        {
                            "variable": out_vars_dict[var_id],
                            "modelling_alternative": "First Principles", 
                            "test_id": item["test_id"],
                            "metrics": metrics_dict,
                            "sample_time": selected_sample_time,
                            "alternative": selected_alternative
                        }
                    )
                    logger.info(f"Added data for variable: {var_id}, test id: {item['test_id']}, alternative: {selected_alternative}, sample time: {selected_sample_time} s")
                    
                # Compute average for each metric
                average_metrics = {metric: np.mean(values) for metric, values in metric_values.items()}
                # (Optional) Also compute standard deviation or median
                std_metrics = {metric: np.std(values) for metric, values in metric_values.items()}
                
                [
                    metric_vals.update({"avg_val": average_metrics[metric_id]}) 
                    for data in table_data for metric_id, metric_vals in data["metrics"].items()
                ]

                table_data_total.extend(table_data)
    
    return table_data_total
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Solar field

# %%
# Load result
from solarmed_modeling.solar_field.benchmark import model_id

out_vars_dict = {
    "Tsf_out": "T$_{sf,out}$ ($^\\circ$C)",
}
out_var_ids = list(out_vars_dict.keys())

# eval_date_str = "20250720"
selected_alternatives: list[str] = ["constant-water-props"]
selected_sample_times: list[int] = [5, 400]

stats = import_benchmark_results(results_path=results_path, model_id=model_id, eval_date_str=eval_date_str)
# stats

# %%
# Parse results dict into compatible format for latex table

table_data = parse_benchmark_results_to_latex_data(
    selected_alternatives=selected_alternatives,
    selected_sample_times=selected_sample_times,
    out_var_ids=out_var_ids,
    stats=stats,
    out_vars_dict=out_vars_dict,
)
# Out:
# 2025-07-20 17:04:12.034 | INFO     | __main__:parse_benchmark_results_to_latex_data:101 - Processing alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.036 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.037 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.037 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.038 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.039 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.040 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.041 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.041 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.042 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.043 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231031, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.044 | INFO     | __main__:parse_benchmark_results_to_latex_data:101 - Processing alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.044 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.045 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.045 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.046 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230703, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.036 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.037 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.037 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.038 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.039 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.040 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.041 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.041 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.042 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.043 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231031, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:12.044 | INFO     | __main__:parse_benchmark_results_to_latex_data:101 - Processing alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.044 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.045 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.045 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.046 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230703, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.047 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230508, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.047 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230628, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.048 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230511, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.049 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230629, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.049 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20230505, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:12.050 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Tsf_out, test id: 20231031, alternative: constant-water-props, sample time: 400 s

# %%
table_str = generate_latex_table(
    regular_col_ids,
    regular_col_labels,
    metric_info,
    table_data,
    submetric_ids,
    group_row_ids,
    submetric_labels,
    group_submetric_ids
)

print(table_str)
# Out:
# \begin{tabular}{ccccccccccccccccccccc}
# \hline
# \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Predicted\\ variable\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Sample\\ time\\ (s)\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Test\\ date\end{tabular}}} &  & \multicolumn{15}{c}{\textbf{Performance metric}}
# \\\cline{7-21}
#  &  &  &  &  &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}R$^2$\\ (-)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAE\\ (s.u.)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAPE\\ (\%)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}Time\\ (s)\end{tabular}}}
#  \\\cline{7-9}\cline{11-13}\cline{15-17}\cline{19-21}
#  &  &  &  &  &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg.
#  \\\cline{1-1}\cline{3-3}\cline{5-5}\cline{7-7}\cline{9-9}\cline{11-11}\cline{13-13}\cline{15-15}\cline{17-17}\cline{19-19}\cline{21-21}
# \multirow{20}{*}{T$_{sf,out}$ ($^\circ$C)} &  & \multirow{10}{*}{5} &  & 20231030 &  & 0.97 &  & \multirow{10}{*}{0.96} &  & 4.41 &  & \multirow{10}{*}{2.50} &  & 9.17 &  & \multirow{10}{*}{9.37} &  & 1.48 &  & \multirow{10}{*}{1.43} \\
#  &  &  &  & 20231106 &  & 0.97 &  &  &  & 2.97 &  &  &  & 6.25 &  &  &  & 1.40 &  &  \\
#  &  &  &  & 20230630 &  & 0.81 &  &  &  & 9.77 &  &  &  & 17.95 &  &  &  & 1.70 &  &  \\
#  &  &  &  & 20230703 &  & 0.92 &  &  &  & 5.07 &  &  &  & 6.05 &  &  &  & 1.60 &  &  \\
#  &  &  &  & 20230508 &  & 0.89 &  &  &  & 5.59 &  &  &  & 7.86 &  &  &  & 1.42 &  &  \\
#  &  &  &  & 20230628 &  & 0.90 &  &  &  & 4.93 &  &  &  & 6.30 &  &  &  & 1.61 &  &  \\
#  &  &  &  & 20230511 &  & 0.87 &  &  &  & 5.02 &  &  &  & 6.30 &  &  &  & 1.43 &  &  \\
#  &  &  &  & 20230629 &  & 0.85 &  &  &  & 7.22 &  &  &  & 11.61 &  &  &  & 1.58 &  &  \\
#  &  &  &  & 20230505 &  & 0.76 &  &  &  & 10.13 &  &  &  & 13.74 &  &  &  & 1.52 &  &  \\
#  &  &  &  & 20231031 &  & 0.96 &  &  &  & 2.50 &  &  &  & 9.37 &  &  &  & 1.43 &  &  \\
#  &  & \multirow{10}{*}{400} &  & 20231030 &  & 0.96 &  & \multirow{10}{*}{0.93} &  & 4.99 &  & \multirow{10}{*}{2.84} &  & 10.71 &  & \multirow{10}{*}{10.21} &  & 0.02 &  & \multirow{10}{*}{0.02} \\
#  &  &  &  & 20231106 &  & 0.97 &  &  &  & 3.69 &  &  &  & 8.28 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230630 &  & 0.79 &  &  &  & 10.20 &  &  &  & 18.52 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230703 &  & 0.93 &  &  &  & 4.73 &  &  &  & 5.56 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230508 &  & 0.88 &  &  &  & 5.71 &  &  &  & 7.81 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230628 &  & 0.91 &  &  &  & 4.74 &  &  &  & 5.92 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230511 &  & 0.80 &  &  &  & 6.15 &  &  &  & 7.64 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230629 &  & 0.87 &  &  &  & 6.93 &  &  &  & 11.03 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20230505 &  & 0.78 &  &  &  & 9.34 &  &  &  & 12.58 &  &  &  & 0.02 &  &  \\
#  &  &  &  & 20231031 &  & 0.93 &  &  &  & 2.84 &  &  &  & 10.21 &  &  &  & 0.02 &  &  \\
# \hline
# \end{tabular}

# %% [markdown]
# ### Thermal storage

# %%
# Load result
from solarmed_modeling.thermal_storage.benchmark import model_id

out_vars_dict = {
    "Tts_h_t": "T$_{ts,h}$ ($^\\circ$C)",
    "Tts_c_b": "T$_{ts,c}$ ($^\\circ$C)",
}
out_var_ids = list(out_vars_dict.keys())

# eval_date_str = "20250720"
selected_alternatives: list[str] = ["constant-water-props"]
selected_sample_times: list[int] = [5, 400]

# (Some tests just don't make sense, the storage is being discharge and it results in increases in temperature??)
filter_out_tests = [
    "20231106",
    "20230703",
    "20231030",
    "20231031"
]

stats = import_benchmark_results(results_path=results_path, model_id=model_id, eval_date_str=eval_date_str)
stats
# Out:
# [{'test_id': '20231030',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 545494119.0963014,
#    'ISE': 635732.1357225121,
#    'IAE': 124111.9465098776,
#    'RMSE': 3.8358803490438196,
#    'MAE': 2.8725627577160022,
#    'MSE': 14.713978052180535,
#    'R2': 0.6330624236677767,
#    'NRMSE': 0.6057537258096093,
#    'MAPE': 3.3938568239624196},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.884866627730137,
#     'MAE': 2.3534974221436697,
#     'MSE': 8.322455459791053,
#     'R2': -0.5325974728270904,
#     'NRMSE': 1.2379812085920732,
#     'MAPE': 2.5191114800507455},
#    'Tts_h_m': {'RMSE': 3.4259875156950113,
#     'MAE': 2.1337811810681644,
#     'MSE': 11.737390457698075,
#     'R2': 0.3915097525162773,
#     'NRMSE': 0.780057848805922,
#     'MAPE': 2.474390912832649},
#    'Tts_h_b': {'RMSE': 5.662426299598112,
#     'MAE': 4.631098762150047,
#     'MSE': 32.06307159838036,
#     'R2': -0.8032862802461804,
#     'NRMSE': 1.3428649523485898,
#     'MAPE': 5.532194794894417},
#    'Tts_c_t': {'RMSE': 4.667420188474347,
#     'MAE': 3.7651987924691306,
#     'MSE': 21.78481121577791,
#     'R2': 0.11009352568796549,
#     'NRMSE': 0.9433485433878797,
#     'MAPE': 4.51823312418328},
#    'Tts_c_m': {'RMSE': 3.07909627020686,
#     'MAE': 2.4958217891967873,
#     'MSE': 9.480833841201797,
#     'R2': 0.5184296925369027,
#     'NRMSE': 0.6939526694689612,
#     'MAPE': 3.005270821302585},
#    'Tts_c_b': {'RMSE': 2.212533782845812,
#     'MAE': 1.8559785992682167,
#     'MSE': 4.895305740233998,
#     'R2': 0.7618813725067991,
#     'NRMSE': 0.48797400288663006,
#     'MAPE': 2.313939810510844}},
#   'elapsed_time': 9.302017450332642,
#   'average_elapsed_time': 0.0012917674559550954,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231030',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 544233790.0679647,
#    'ISE': 632979.7701530942,
#    'IAE': 123989.17051608687,
#    'RMSE': 3.8275677308056717,
#    'MAE': 2.869721115495229,
#    'MSE': 14.65027473390488,
#    'R2': 0.6346510587146345,
#    'NRMSE': 0.6044410155551703,
#    'MAPE': 3.389884204955747},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.9056033534714163,
#     'MAE': 2.369002286252361,
#     'MSE': 8.44253084770434,
#     'R2': -0.5547096051122966,
#     'NRMSE': 1.2468799481555137,
#     'MAPE': 2.535590265483768},
#    'Tts_h_m': {'RMSE': 3.4209791252062023,
#     'MAE': 2.1390152814944217,
#     'MSE': 11.703098175096592,
#     'R2': 0.393287534349655,
#     'NRMSE': 0.7789174960484229,
#     'MAPE': 2.479362715477824},
#    'Tts_h_b': {'RMSE': 5.641626027832325,
#     'MAE': 4.618019611789831,
#     'MSE': 31.827944237915137,
#     'R2': -0.7900622838509359,
#     'NRMSE': 1.33793209239144,
#     'MAPE': 5.51660749355898},
#    'Tts_c_t': {'RMSE': 4.652952963582742,
#     'MAE': 3.7557769275022066,
#     'MSE': 21.64997128131342,
#     'R2': 0.11560171804672481,
#     'NRMSE': 0.9404245221990306,
#     'MAPE': 4.506360541032276},
#    'Tts_c_m': {'RMSE': 3.0689784989296878,
#     'MAE': 2.4882933184758373,
#     'MSE': 9.418629026892718,
#     'R2': 0.5215893293425099,
#     'NRMSE': 0.6916723723393108,
#     'MAPE': 2.996138317953792},
#    'Tts_c_b': {'RMSE': 2.204421655334359,
#     'MAE': 1.8482192674567153,
#     'MSE': 4.8594748345070755,
#     'R2': 0.7636242679552712,
#     'NRMSE': 0.48618487434794677,
#     'MAPE': 2.3052458962278393}},
#   'elapsed_time': 5.402311563491821,
#   'average_elapsed_time': 0.0007502168536997391,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231030',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 545747720.7240301,
#    'ISE': 636255.3279974159,
#    'IAE': 124233.7199436084,
#    'RMSE': 3.837458443114353,
#    'MAE': 2.875381195750785,
#    'MSE': 14.726087302629633,
#    'R2': 0.6327604428577447,
#    'NRMSE': 0.6060029349287472,
#    'MAPE': 3.397248515015087},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.8812496693073992,
#     'MAE': 2.351179711086222,
#     'MSE': 8.301599656883997,
#     'R2': -0.5287568333687525,
#     'NRMSE': 1.2364290652393903,
#     'MAPE': 2.5165125728500355},
#    'Tts_h_m': {'RMSE': 3.4312756875953587,
#     'MAE': 2.137830008375332,
#     'MSE': 11.773652844283003,
#     'R2': 0.3896298364764269,
#     'NRMSE': 0.7812619045643868,
#     'MAPE': 2.479023812393797},
#    'Tts_h_b': {'RMSE': 5.659774598137141,
#     'MAE': 4.62915489747779,
#     'MSE': 32.03304850171844,
#     'R2': -0.8015977259186629,
#     'NRMSE': 1.3422360917210738,
#     'MAPE': 5.529741660444384},
#    'Tts_c_t': {'RMSE': 4.665506222031186,
#     'MAE': 3.7668613506616255,
#     'MSE': 21.76694830781171,
#     'R2': 0.11082322296611546,
#     'NRMSE': 0.9429617049667948,
#     'MAPE': 4.520089913981782},
#    'Tts_c_m': {'RMSE': 3.0844859454393414,
#     'MAE': 2.5018444064551297,
#     'MSE': 9.514053547612827,
#     'R2': 0.5167423278495615,
#     'NRMSE': 0.6951673698832811,
#     'MAPE': 3.0123878497618124},
#    'Tts_c_b': {'RMSE': 2.2287263083357285,
#     'MAE': 1.8654168004486091,
#     'MSE': 4.967220957467804,
#     'R2': 0.7583832553855648,
#     'NRMSE': 0.4915452620201269,
#     'MAPE': 2.325735280658709}},
#   'elapsed_time': 1.4795477390289307,
#   'average_elapsed_time': 0.0012319298409899505,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231030',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 544489275.7379242,
#    'ISE': 633476.9374965768,
#    'IAE': 124110.4405178063,
#    'RMSE': 3.82907059729185,
#    'MAE': 2.872527901629549,
#    'MSE': 14.661781639044966,
#    'R2': 0.6343640992079521,
#    'NRMSE': 0.6046783449008637,
#    'MAPE': 3.3932796655908497},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.9017329120491597,
#     'MAE': 2.3665295258272483,
#     'MSE': 8.420053892869298,
#     'R2': -0.5505704271565277,
#     'NRMSE': 1.2452190277844808,
#     'MAPE': 2.5328281674314788},
#    'Tts_h_m': {'RMSE': 3.42602722593605,
#     'MAE': 2.1428769153860787,
#     'MSE': 11.737662552855063,
#     'R2': 0.39149564654868485,
#     'NRMSE': 0.7800668903698676,
#     'MAPE': 2.4837953097709944},
#    'Tts_h_b': {'RMSE': 5.638825055203341,
#     'MAE': 4.61593880581582,
#     'MSE': 31.796348003188967,
#     'R2': -0.7882852533373648,
#     'NRMSE': 1.337267831564554,
#     'MAPE': 5.5139975370691525},
#    'Tts_c_t': {'RMSE': 4.651094919475616,
#     'MAE': 3.7574625831159083,
#     'MSE': 21.632683949971888,
#     'R2': 0.11630790310070704,
#     'NRMSE': 0.9400489864359691,
#     'MAPE': 4.508252533012984},
#    'Tts_c_m': {'RMSE': 3.0744263358550685,
#     'MAE': 2.4943542686767146,
#     'MSE': 9.452097294599223,
#     'R2': 0.5198893392108785,
#     'NRMSE': 0.6929001809706224,
#     'MAPE': 3.003305323427832},
#    'Tts_c_b': {'RMSE': 2.2207755719084576,
#     'MAE': 1.8580053109555248,
#     'MSE': 4.931844140785336,
#     'R2': 0.7601040629266083,
#     'NRMSE': 0.4897917282615048,
#     'MAPE': 2.317499122832659}},
#   'elapsed_time': 0.9139368534088135,
#   'average_elapsed_time': 0.000760979894595182,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231030',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 547415814.990139,
#    'ISE': 644409.6384825655,
#    'IAE': 125536.112675257,
#    'RMSE': 3.8619707763201063,
#    'MAE': 2.905524989012105,
#    'MSE': 14.914818277150523,
#    'R2': 0.6280538647913697,
#    'NRMSE': 0.6098738682782123,
#    'MAPE': 3.4317117820294922},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.835318795940048,
#     'MAE': 2.3257479770439464,
#     'MSE': 8.039032674610924,
#     'R2': -0.48040457778459955,
#     'NRMSE': 1.2167187751426372,
#     'MAPE': 2.488671305857669},
#    'Tts_h_m': {'RMSE': 3.4821110079954143,
#     'MAE': 2.1776763576617624,
#     'MSE': 12.125097072002841,
#     'R2': 0.3714102513077564,
#     'NRMSE': 0.7928365207861224,
#     'MAPE': 2.5254722934376463},
#    'Tts_h_b': {'RMSE': 5.694846973233508,
#     'MAE': 4.681458308673867,
#     'MSE': 32.43128204854685,
#     'R2': -0.8239951150498315,
#     'NRMSE': 1.3505536327928007,
#     'MAPE': 5.590491492019741},
#    'Tts_c_t': {'RMSE': 4.613374022981942,
#     'MAE': 3.7558011566136313,
#     'MSE': 21.283219875924587,
#     'R2': 0.13058346137632415,
#     'NRMSE': 0.9324250847245991,
#     'MAPE': 4.505520666802904},
#    'Tts_c_m': {'RMSE': 3.1205783245969028,
#     'MAE': 2.5406616376711275,
#     'MSE': 9.738009079944012,
#     'R2': 0.5053667108554006,
#     'NRMSE': 0.7033017056318002,
#     'MAPE': 3.0550523072892015},
#    'Tts_c_b': {'RMSE': 2.4232764827550985,
#     'MAE': 1.9518044964082923,
#     'MSE': 5.872268911873922,
#     'R2': 0.7143596972761151,
#     'NRMSE': 0.5344532745936588,
#     'MAPE': 2.4250626267697895}},
#   'elapsed_time': 0.10948038101196289,
#   'average_elapsed_time': 0.0012030811100215701,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231030',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 546194589.143017,
#    'ISE': 641486.414157988,
#    'IAE': 125410.28820248968,
#    'RMSE': 3.8532013241376526,
#    'MAE': 2.9026127899479164,
#    'MSE': 14.847160444336158,
#    'R2': 0.6297411176270579,
#    'NRMSE': 0.6084890158194659,
#    'MAPE': 3.4277829603410135},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 2.854133495778536,
#     'MAE': 2.340073813242436,
#     'MSE': 8.146078011725008,
#     'R2': -0.500117199129537,
#     'NRMSE': 1.224792716801311,
#     'MAPE': 2.5039114654609493},
#    'Tts_h_m': {'RMSE': 3.4755409336311107,
#     'MAE': 2.1816368421957177,
#     'MSE': 12.079384781345414,
#     'R2': 0.37378006963794086,
#     'NRMSE': 0.7913405906195252,
#     'MAPE': 2.5291044610472837},
#    'Tts_h_b': {'RMSE': 5.672628112758306,
#     'MAE': 4.66682142439854,
#     'MSE': 32.17870970565586,
#     'R2': -0.8097899806693822,
#     'NRMSE': 1.3452843493735376,
#     'MAPE': 5.5731265547618705},
#    'Tts_c_t': {'RMSE': 4.599794592390341,
#     'MAE': 3.7468115041445684,
#     'MSE': 21.15811029218343,
#     'R2': 0.13569417027652808,
#     'NRMSE': 0.9296804987324795,
#     'MAPE': 4.494243759510527},
#    'Tts_c_m': {'RMSE': 3.1113102063425293,
#     'MAE': 2.533635930841168,
#     'MSE': 9.680251200091192,
#     'R2': 0.5083004696813662,
#     'NRMSE': 0.701212899424015,
#     'MAPE': 3.0465768776948905},
#    'Tts_c_b': {'RMSE': 2.4166978865832727,
#     'MAE': 1.9466972248650682,
#     'MSE': 5.840428675016056,
#     'R2': 0.7159084776591952,
#     'NRMSE': 0.5330023661681107,
#     'MAPE': 2.4197346435705627}},
#   'elapsed_time': 0.06582307815551758,
#   'average_elapsed_time': 0.0007233305291815119,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231030',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 532997000.1551583,
#    'ISE': 716408.0597549279,
#    'IAE': 128641.34419773018,
#    'RMSE': 4.072004046527354,
#    'MAE': 2.9773953663317636,
#    'MSE': 16.581216954935144,
#    'R2': 0.5864971702074129,
#    'NRMSE': 0.6430418569522416,
#    'MAPE': 3.493035347733949},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 3.114703694786896,
#     'MAE': 2.55016982269676,
#     'MSE': 9.701379106319141,
#     'R2': -0.7865291287068712,
#     'NRMSE': 1.3366110611194533,
#     'MAPE': 2.7248201062026016},
#    'Tts_h_m': {'RMSE': 3.744786660831105,
#     'MAE': 2.4909385330361817,
#     'MSE': 14.023427135138578,
#     'R2': 0.2729969511720637,
#     'NRMSE': 0.8526447377588957,
#     'MAPE': 2.8609845616006933},
#    'Tts_h_b': {'RMSE': 6.125205195577433,
#     'MAE': 4.897824876914793,
#     'MSE': 37.518138687928776,
#     'R2': -1.1100893140797203,
#     'NRMSE': 1.4526146474821602,
#     'MAPE': 5.821041107916327},
#    'Tts_c_t': {'RMSE': 4.4158939669207795,
#     'MAE': 3.6273279877649487,
#     'MSE': 19.500119527087335,
#     'R2': 0.2034228598480935,
#     'NRMSE': 0.8925117030896046,
#     'MAPE': 4.327819025687183},
#    'Tts_c_m': {'RMSE': 3.122433504450875,
#     'MAE': 2.4137366629064916,
#     'MSE': 9.749590989717372,
#     'R2': 0.504778418312362,
#     'NRMSE': 0.7037198176033114,
#     'MAPE': 2.877132902973304},
#    'Tts_c_b': {'RMSE': 2.999107581168052,
#     'MAE': 1.8843743146714083,
#     'MSE': 8.994646283419682,
#     'R2': 0.5624802736647179,
#     'NRMSE': 0.6614527393059024,
#     'MAPE': 2.346414382023585}},
#   'elapsed_time': 0.04425525665283203,
#   'average_elapsed_time': 0.001196088017644109,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20231030',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 531753691.8707079,
#    'ISE': 712991.0927543227,
#    'IAE': 128448.31019941696,
#    'RMSE': 4.062281560980412,
#    'MAE': 2.9729276072632724,
#    'MSE': 16.50213148068145,
#    'R2': 0.5884694058695039,
#    'NRMSE': 0.6415065035761494,
#    'MAPE': 3.487462904983062},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 3.1272433106789186,
#     'MAE': 2.560513072686156,
#     'MSE': 9.779650724186045,
#     'R2': -0.8009430098404466,
#     'NRMSE': 1.341992179500479,
#     'MAPE': 2.735872086312891},
#    'Tts_h_m': {'RMSE': 3.7343150693475353,
#     'MAE': 2.490912812611477,
#     'MSE': 13.945109037156088,
#     'R2': 0.2770571210194904,
#     'NRMSE': 0.850260477136571,
#     'MAPE': 2.8604077448162823},
#    'Tts_h_b': {'RMSE': 6.099430487900984,
#     'MAE': 4.878850648370452,
#     'MSE': 37.20305227673604,
#     'R2': -1.0923682732040056,
#     'NRMSE': 1.4465020819908991,
#     'MAPE': 5.798583442304501},
#    'Tts_c_t': {'RMSE': 4.404603651633747,
#     'MAE': 3.619311795972771,
#     'MSE': 19.400533327985336,
#     'R2': 0.2074909420754395,
#     'NRMSE': 0.8902297781609871,
#     'MAPE': 4.317857796608222},
#    'Tts_c_m': {'RMSE': 3.114735618851049,
#     'MAE': 2.407971589648888,
#     'MSE': 9.70157797533943,
#     'R2': 0.5072171955848561,
#     'NRMSE': 0.7019849032672595,
#     'MAPE': 2.8702374693863817},
#    'Tts_c_b': {'RMSE': 2.997142896607658,
#     'MAE': 1.8800057242898924,
#     'MSE': 8.982865542685742,
#     'R2': 0.5630533152607438,
#     'NRMSE': 0.661019428412854,
#     'MAPE': 2.3418188904700967}},
#   'elapsed_time': 0.02626800537109375,
#   'average_elapsed_time': 0.0007099460911106419,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20231106',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 1111173651.8383534,
#    'ISE': 3160527.1636996362,
#    'IAE': 279538.6644384919,
#    'RMSE': 8.552788508011826,
#    'MAE': 6.469903819804933,
#    'MSE': 73.15019126277916,
#    'R2': 0.21929829611450713,
#    'NRMSE': 0.8835732589239519,
#    'MAPE': 7.548236718397624},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.696077042446967,
#     'MAE': 3.792709127209798,
#     'MSE': 22.053139588597446,
#     'R2': -2.0111110000059376,
#     'NRMSE': 1.7352553126286454,
#     'MAPE': 4.238132203765259},
#    'Tts_h_m': {'RMSE': 7.091963562187782,
#     'MAE': 5.419119946943575,
#     'MSE': 50.29594716739922,
#     'R2': -6.833837434557216,
#     'NRMSE': 2.798899325548744,
#     'MAPE': 6.066716644019639},
#    'Tts_h_b': {'RMSE': 12.829599661272244,
#     'MAE': 10.243940653417903,
#     'MSE': 164.59862746851687,
#     'R2': -5.385685147594839,
#     'NRMSE': 2.5269913232132075,
#     'MAPE': 11.621834410696843},
#    'Tts_c_t': {'RMSE': 9.54698931472936,
#     'MAE': 8.271936120412215,
#     'MSE': 91.14500497555659,
#     'R2': -35.00393312168257,
#     'NRMSE': 6.000327751188478,
#     'MAPE': 9.14150773998048},
#    'Tts_c_m': {'RMSE': 9.978950141569342,
#     'MAE': 8.036724169238905,
#     'MSE': 99.57944592792678,
#     'R2': 0.23993792536045844,
#     'NRMSE': 0.8718153902286547,
#     'MAPE': 9.680194791491493},
#    'Tts_c_b': {'RMSE': 3.3509673899753194,
#     'MAE': 3.054992901607198,
#     'MSE': 11.228982448678005,
#     'R2': -1.1589209301814,
#     'NRMSE': 1.4693266928023188,
#     'MAPE': 4.541034520432033}},
#   'elapsed_time': 8.854676008224487,
#   'average_elapsed_time': 0.0012296453281800427,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231106',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 1117395253.7335882,
#    'ISE': 3192143.310335611,
#    'IAE': 281058.6704404662,
#    'RMSE': 8.595460713454278,
#    'MAE': 6.50508425775277,
#    'MSE': 73.88194487653593,
#    'R2': 0.21148859277371823,
#    'NRMSE': 0.8879816480233598,
#    'MAPE': 7.585622305335018},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.763588453854338,
#     'MAE': 3.843597138926451,
#     'MSE': 22.69177495769436,
#     'R2': -2.0983095586127525,
#     'NRMSE': 1.760201567608878,
#     'MAPE': 4.294408841318411},
#    'Tts_h_m': {'RMSE': 7.190844533491961,
#     'MAE': 5.495143328630185,
#     'MSE': 51.708245104851216,
#     'R2': -7.053809680319608,
#     'NRMSE': 2.8379234803496036,
#     'MAPE': 6.151764641626921},
#    'Tts_h_b': {'RMSE': 12.876793951596303,
#     'MAE': 10.305717893706728,
#     'MSE': 165.81182247186712,
#     'R2': -5.432751647681614,
#     'NRMSE': 2.5362869805449093,
#     'MAPE': 11.692316704703337},
#    'Tts_c_t': {'RMSE': 9.591623011856917,
#     'MAE': 8.311746127195649,
#     'MSE': 91.99923200158317,
#     'R2': -35.34136831875171,
#     'NRMSE': 6.028380240060486,
#     'MAPE': 9.185896326530509},
#    'Tts_c_m': {'RMSE': 10.001444620195803,
#     'MAE': 8.044564126629217,
#     'MSE': 100.02889449084357,
#     'R2': 0.2365074101171668,
#     'NRMSE': 0.8737806302973493,
#     'MAPE': 9.685646091946932},
#    'Tts_c_b': {'RMSE': 3.324409756990873,
#     'MAE': 3.029736931428395,
#     'MSE': 11.051700232376113,
#     'R2': -1.1248360708388545,
#     'NRMSE': 1.457681745388497,
#     'MAPE': 4.503701225883992}},
#   'elapsed_time': 5.308424234390259,
#   'average_elapsed_time': 0.0007371787577267405,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231106',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 1110872640.8342092,
#    'ISE': 3154733.734002515,
#    'IAE': 279520.9535656443,
#    'RMSE': 8.544946033608019,
#    'MAE': 6.469493902829336,
#    'MSE': 73.01610271727341,
#    'R2': 0.22072936764201423,
#    'NRMSE': 0.8827630669426456,
#    'MAPE': 7.548520124583908},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.693188021516962,
#     'MAE': 3.7942430322879415,
#     'MSE': 22.026013805310292,
#     'R2': -2.00740727591207,
#     'NRMSE': 1.7341877856541572,
#     'MAPE': 4.239507779488538},
#    'Tts_h_m': {'RMSE': 7.078389239492078,
#     'MAE': 5.412489581861889,
#     'MSE': 50.10359422575724,
#     'R2': -6.8038775320253695,
#     'NRMSE': 2.7935421120909147,
#     'MAPE': 6.059092304656851},
#    'Tts_h_b': {'RMSE': 12.815387000080571,
#     'MAE': 10.239222887731868,
#     'MSE': 164.23414396183412,
#     'R2': -5.3715448297139226,
#     'NRMSE': 2.5241919161810817,
#     'MAPE': 11.616851698837069},
#    'Tts_c_t': {'RMSE': 9.536907015753602,
#     'MAE': 8.268639846537393,
#     'MSE': 90.95259542713028,
#     'R2': -34.927927853863764,
#     'NRMSE': 5.993990978793993,
#     'MAPE': 9.137612426018183},
#    'Tts_c_m': {'RMSE': 9.974676544760872,
#     'MAE': 8.03941836787569,
#     'MSE': 99.49417217260269,
#     'R2': 0.24058879609768724,
#     'NRMSE': 0.8714420255543753,
#     'MAPE': 9.685167981586263},
#    'Tts_c_b': {'RMSE': 3.3594786367836678,
#     'MAE': 3.0629497006812243,
#     'MSE': 11.286096711005852,
#     'R2': -1.1699019052532753,
#     'NRMSE': 1.4730586903627687,
#     'MAPE': 4.552888556916544}},
#   'elapsed_time': 1.4730753898620605,
#   'average_elapsed_time': 0.0012265407076286932,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231106',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 1117066031.7277243,
#    'ISE': 3186062.373993049,
#    'IAE': 281030.6172851936,
#    'RMSE': 8.587269764530479,
#    'MAE': 6.504434969337444,
#    'MSE': 73.74120200881936,
#    'R2': 0.21299068312699343,
#    'NRMSE': 0.8871354557636656,
#    'MAPE': 7.585635016941733},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.760197420464093,
#     'MAE': 3.844829340688201,
#     'MSE': 22.659479481793,
#     'R2': -2.0938999704746855,
#     'NRMSE': 1.7589485411673318,
#     'MAPE': 4.295449303445487},
#    'Tts_h_m': {'RMSE': 7.176088548322169,
#     'MAE': 5.487770621609381,
#     'MSE': 51.49624685336058,
#     'R2': -7.020789925605365,
#     'NRMSE': 2.8320999144813666,
#     'MAPE': 6.143315624466162},
#    'Tts_h_b': {'RMSE': 12.862177337339187,
#     'MAE': 10.300709156338344,
#     'MSE': 165.43560585716176,
#     'R2': -5.418156138072872,
#     'NRMSE': 2.5334080086067603,
#     'MAPE': 11.687002713208168},
#    'Tts_c_t': {'RMSE': 9.581469965673513,
#     'MAE': 8.3083861253801,
#     'MSE': 91.8045667031036,
#     'R2': -35.26447198867361,
#     'NRMSE': 6.021999002712771,
#     'MAPE': 9.181928303077767},
#    'Tts_c_m': {'RMSE': 9.997143026415404,
#     'MAE': 8.047258886651846,
#     'MSE': 99.94286869060615,
#     'R2': 0.2371640210029946,
#     'NRMSE': 0.8734048196552416,
#     'MAPE': 9.690623555877247},
#    'Tts_c_b': {'RMSE': 3.3329333126978407,
#     'MAE': 3.0376556853567833,
#     'MSE': 11.108444466891001,
#     'R2': -1.1357459031519097,
#     'NRMSE': 1.4614191401346535,
#     'MAPE': 4.515490601575571}},
#   'elapsed_time': 0.9001419544219971,
#   'average_elapsed_time': 0.0007494937172539526,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231106',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 1133772318.777348,
#    'ISE': 3356098.9239489366,
#    'IAE': 289196.9480279063,
#    'RMSE': 8.813437845852627,
#    'MAE': 6.693444151921176,
#    'MSE': 77.67668666270741,
#    'R2': 0.17098888488331665,
#    'NRMSE': 0.9105004750776813,
#    'MAPE': 7.801875672869932},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.874978278826706,
#     'MAE': 3.9534294915962453,
#     'MSE': 23.765413219032194,
#     'R2': -2.244902925319284,
#     'NRMSE': 1.801361408857002,
#     'MAPE': 4.412562334530206},
#    'Tts_h_m': {'RMSE': 7.385217385271721,
#     'MAE': 5.665228255093679,
#     'MSE': 54.54143582771968,
#     'R2': -7.4950928610533705,
#     'NRMSE': 2.9146342585397176,
#     'MAPE': 6.336762830049239},
#    'Tts_h_b': {'RMSE': 13.30708905849688,
#     'MAE': 10.705168382478483,
#     'MSE': 177.07861921076736,
#     'R2': -5.869852598662063,
#     'NRMSE': 2.6210403657063472,
#     'MAPE': 12.161830734475894},
#    'Tts_c_t': {'RMSE': 9.72575878184248,
#     'MAE': 8.50661902225131,
#     'MSE': 94.5903838825861,
#     'R2': -36.364920394444404,
#     'NRMSE': 6.1126852032837755,
#     'MAPE': 9.396350535213385},
#    'Tts_c_m': {'RMSE': 10.122893996952277,
#     'MAE': 8.169523840045796,
#     'MSE': 102.47298287353244,
#     'R2': 0.21785236670496066,
#     'NRMSE': 0.8843911087833477,
#     'MAPE': 9.79862798316201},
#    'Tts_c_b': {'RMSE': 3.6893474982179124,
#     'MAE': 3.1606959200615363,
#     'MSE': 13.611284962606769,
#     'R2': -1.6169502113608436,
#     'NRMSE': 1.6176990484514862,
#     'MAPE': 4.70511961978886}},
#   'elapsed_time': 0.10973906517028809,
#   'average_elapsed_time': 0.0012059237930800888,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231106',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 1139956125.120038,
#    'ISE': 3387500.0390678667,
#    'IAE': 290694.96865077177,
#    'RMSE': 8.854573021116595,
#    'MAE': 6.728115739729939,
#    'MSE': 78.40346338628586,
#    'R2': 0.1632322978307451,
#    'NRMSE': 0.9147500763428529,
#    'MAPE': 7.83883669987133},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.941193641386113,
#     'MAE': 4.003686780152737,
#     'MSE': 24.41539460167456,
#     'R2': -2.333650655918398,
#     'NRMSE': 1.8258287586513684,
#     'MAPE': 4.468126757366193},
#    'Tts_h_m': {'RMSE': 7.478524271728207,
#     'MAE': 5.738572611222933,
#     'MSE': 55.928325282827906,
#     'R2': -7.7111076125970435,
#     'NRMSE': 2.951458556815095,
#     'MAPE': 6.418839884892109},
#    'Tts_h_b': {'RMSE': 13.351472091499147,
#     'MAE': 10.766395113035111,
#     'MSE': 178.2618070100806,
#     'R2': -5.915754954429489,
#     'NRMSE': 2.6297823017180506,
#     'MAPE': 12.23192326190844},
#    'Tts_c_t': {'RMSE': 9.769600362304647,
#     'MAE': 8.545973295860076,
#     'MSE': 95.4450912391431,
#     'R2': -36.70254533080094,
#     'NRMSE': 6.14023984310067,
#     'MAPE': 9.440214146533718},
#    'Tts_c_m': {'RMSE': 10.144677193906938,
#     'MAE': 8.177188249812529,
#     'MSE': 102.91447536857554,
#     'R2': 0.21448257790373437,
#     'NRMSE': 0.8862942074143696,
#     'MAPE': 9.803995765553701},
#    'Tts_c_b': {'RMSE': 3.6681993968994404,
#     'MAE': 3.136878388296257,
#     'MSE': 13.455686815413419,
#     'R2': -1.5870344021405058,
#     'NRMSE': 1.6084260636226042,
#     'MAPE': 4.669920382973831}},
#   'elapsed_time': 0.06599092483520508,
#   'average_elapsed_time': 0.0007251749981890668,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231106',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 1130125274.634386,
#    'ISE': 3362608.162430392,
#    'IAE': 291325.035602125,
#    'RMSE': 8.821980648073215,
#    'MAE': 6.742698597466208,
#    'MSE': 77.82734255497829,
#    'R2': 0.16938099692341035,
#    'NRMSE': 0.9113830166711413,
#    'MAPE': 7.867962960729552},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.917096955881535,
#     'MAE': 4.015344720077784,
#     'MSE': 24.177842473539453,
#     'R2': -2.3012155541847523,
#     'NRMSE': 1.8169247519324383,
#     'MAPE': 4.476715847996146},
#    'Tts_h_m': {'RMSE': 7.296730183132603,
#     'MAE': 5.628232949250093,
#     'MSE': 53.24227136543834,
#     'R2': -7.292741702134093,
#     'NRMSE': 2.879712086673613,
#     'MAPE': 6.289509337018047},
#    'Tts_h_b': {'RMSE': 13.483490485766255,
#     'MAE': 10.95478827944193,
#     'MSE': 181.80451567974913,
#     'R2': -6.053196089158786,
#     'NRMSE': 2.655785399681003,
#     'MAPE': 12.462581590838862},
#    'Tts_c_t': {'RMSE': 9.424014583407514,
#     'MAE': 8.315964311644834,
#     'MSE': 88.81205086827751,
#     'R2': -34.08237385821052,
#     'NRMSE': 5.923037553334481,
#     'MAPE': 9.182142970785758},
#    'Tts_c_m': {'RMSE': 10.132033182416693,
#     'MAE': 8.259449081529292,
#     'MSE': 102.65809640959294,
#     'R2': 0.2164394468302725,
#     'NRMSE': 0.885189557761346,
#     'MAPE': 9.907103187082173},
#    'Tts_c_b': {'RMSE': 4.033519373112321,
#     'MAE': 3.2824122428533147,
#     'MSE': 16.269278533272406,
#     'R2': -2.127984757743381,
#     'NRMSE': 1.7686109684561444,
#     'MAPE': 4.889724830656325}},
#   'elapsed_time': 0.04425692558288574,
#   'average_elapsed_time': 0.0011961331238617768,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20231106',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 1136006346.2189906,
#    'ISE': 3392082.583123737,
#    'IAE': 292749.98790012917,
#    'RMSE': 8.860560143922003,
#    'MAE': 6.775679023749691,
#    'MSE': 78.50952606405909,
#    'R2': 0.16210033478558006,
#    'NRMSE': 0.9153685952742864,
#    'MAPE': 7.902931173881679},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 4.979518116106701,
#     'MAE': 4.0630476091330925,
#     'MSE': 24.795600668634822,
#     'R2': -2.385563566816807,
#     'NRMSE': 1.8399900996518452,
#     'MAPE': 4.529456742131517},
#    'Tts_h_m': {'RMSE': 7.3835051546287085,
#     'MAE': 5.697262178408113,
#     'MSE': 54.5161483684287,
#     'R2': -7.491154216761432,
#     'NRMSE': 2.913958513218991,
#     'MAPE': 6.366746813524932},
#    'Tts_h_b': {'RMSE': 13.52143126041409,
#     'MAE': 11.011560145024434,
#     'MSE': 182.82910333010335,
#     'R2': -6.092945473718676,
#     'NRMSE': 2.6632584316432144,
#     'MAPE': 12.52782246833252},
#    'Tts_c_t': {'RMSE': 9.47062109487049,
#     'MAE': 8.357348046669138,
#     'MSE': 89.69266392260592,
#     'R2': -34.430232015907954,
#     'NRMSE': 5.952329965308372,
#     'MAPE': 9.22812570692602},
#    'Tts_c_m': {'RMSE': 10.154659322982987,
#     'MAE': 8.267630221662701,
#     'MSE': 103.1171059658453,
#     'R2': 0.21293595519750075,
#     'NRMSE': 0.8871663005336142,
#     'MAPE': 9.912932796366142},
#    'Tts_c_b': {'RMSE': 4.013294672552266,
#     'MAE': 3.2572259416006633,
#     'MSE': 16.106534128736396,
#     'R2': -2.0966949856889174,
#     'NRMSE': 1.759742874879429,
#     'MAPE': 4.852502516008946}},
#   'elapsed_time': 0.026308298110961914,
#   'average_elapsed_time': 0.0007110350840800518,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20230630',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 287306836.125848,
#    'ISE': 206409.23958724056,
#    'IAE': 71008.0820355393,
#    'RMSE': 2.0840058566266264,
#    'MAE': 1.4940891729903483,
#    'MSE': 4.343080410454079,
#    'R2': 0.8460353891817951,
#    'NRMSE': 0.3923832448234824,
#    'MAPE': 1.6851139518135136},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.496513633030775,
#     'MAE': 0.9791544598284174,
#     'MSE': 2.239553053846969,
#     'R2': 0.15074706114941705,
#     'NRMSE': 0.9215492058759439,
#     'MAPE': 1.0220541429050993},
#    'Tts_h_m': {'RMSE': 1.2057155245639664,
#     'MAE': 0.9647351656513576,
#     'MSE': 1.4537499261745606,
#     'R2': 0.7964253410472784,
#     'NRMSE': 0.4511924854790044,
#     'MAPE': 1.0312901642283254},
#    'Tts_h_b': {'RMSE': 2.8314654509010606,
#     'MAE': 1.9470903905644772,
#     'MSE': 8.017196599646347,
#     'R2': 0.6137717760861163,
#     'NRMSE': 0.6214726252329089,
#     'MAPE': 2.160163872893438},
#    'Tts_c_t': {'RMSE': 2.184679159469401,
#     'MAE': 1.7154085259824097,
#     'MSE': 4.772823029819927,
#     'R2': -0.590718663139491,
#     'NRMSE': 1.2612369575696278,
#     'MAPE': 1.9078161102289029},
#    'Tts_c_m': {'RMSE': 1.8697750659036945,
#     'MAE': 1.2507806002641912,
#     'MSE': 3.4960587970751646,
#     'R2': 0.58227281047009,
#     'NRMSE': 0.6463181797922057,
#     'MAPE': 1.4320906058060194},
#    'Tts_c_b': {'RMSE': 2.465583309515521,
#     'MAE': 2.1073658956512378,
#     'MSE': 6.079101056161508,
#     'R2': 0.51425004651317,
#     'NRMSE': 0.6969576410993928,
#     'MAPE': 2.557268814819298}},
#   'elapsed_time': 9.794508457183838,
#   'average_elapsed_time': 0.0012365242339583181,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20230630',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 288083380.402849,
#    'ISE': 207165.53137972992,
#    'IAE': 71240.2654095014,
#    'RMSE': 2.0878203065714964,
#    'MAE': 1.498974569909132,
#    'MSE': 4.358993632532297,
#    'R2': 0.8454712566278044,
#    'NRMSE': 0.3931014415799002,
#    'MAPE': 1.6903849226987713},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.510829386766306,
#     'MAE': 0.987359499928489,
#     'MSE': 2.2826054359166528,
#     'R2': 0.1344213206475824,
#     'NRMSE': 0.9303648098205444,
#     'MAPE': 1.0306012443521748},
#    'Tts_h_m': {'RMSE': 1.217111289443675,
#     'MAE': 0.9739749179237607,
#     'MSE': 1.4813598908912453,
#     'R2': 0.7925590026559939,
#     'NRMSE': 0.45545691052393333,
#     'MAPE': 1.0412075481472187},
#    'Tts_h_b': {'RMSE': 2.836249513719242,
#     'MAE': 1.9615441942593277,
#     'MSE': 8.044311304072636,
#     'R2': 0.6124655259521259,
#     'NRMSE': 0.6225226695051949,
#     'MAPE': 2.1760652961032916},
#    'Tts_c_t': {'RMSE': 2.184814923415163,
#     'MAE': 1.714140447710893,
#     'MSE': 4.773416249577604,
#     'R2': -0.5909163754229727,
#     'NRMSE': 1.2613153354427165,
#     'MAPE': 1.9064245307268575},
#    'Tts_c_m': {'RMSE': 1.871517128400147,
#     'MAE': 1.2495355925207172,
#     'MSE': 3.5025763618951324,
#     'R2': 0.581494058111262,
#     'NRMSE': 0.646920352044004,
#     'MAPE': 1.4305942418112665},
#    'Tts_c_b': {'RMSE': 2.4636746036846078,
#     'MAE': 2.1072927671116037,
#     'MSE': 6.069692552840508,
#     'R2': 0.5150018320170355,
#     'NRMSE': 0.6964180985463866,
#     'MAPE': 2.5574166750518192}},
#   'elapsed_time': 5.9097888469696045,
#   'average_elapsed_time': 0.0007460912570344154,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20230630',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 287161407.55233455,
#    'ISE': 205431.3853507018,
#    'IAE': 70914.21618958567,
#    'RMSE': 2.079063555463791,
#    'MAE': 1.49211413099326,
#    'MSE': 4.322505267657741,
#    'R2': 0.8467647894124567,
#    'NRMSE': 0.39145269265588567,
#    'MAPE': 1.6829611310780126},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.4918374633367333,
#     'MAE': 0.9781724459307515,
#     'MSE': 2.225579017014979,
#     'R2': 0.15604610589711276,
#     'NRMSE': 0.9186696327314228,
#     'MAPE': 1.0209995512108228},
#    'Tts_h_m': {'RMSE': 1.2053769849568674,
#     'MAE': 0.9651428295325168,
#     'MSE': 1.452933675863708,
#     'R2': 0.7965396439790688,
#     'NRMSE': 0.451065800101195,
#     'MAPE': 1.0315623378500727},
#    'Tts_h_b': {'RMSE': 2.817658323741743,
#     'MAE': 1.9417761054155174,
#     'MSE': 7.939198429351128,
#     'R2': 0.6175293357776155,
#     'NRMSE': 0.618442126817364,
#     'MAPE': 2.1537961614474086},
#    'Tts_c_t': {'RMSE': 2.175365844683512,
#     'MAE': 1.7068672244197955,
#     'MSE': 4.732216558215609,
#     'R2': -0.5771850642983729,
#     'NRMSE': 1.2558602885267027,
#     'MAPE': 1.8983691371767357},
#    'Tts_c_m': {'RMSE': 1.866643300026193,
#     'MAE': 1.2502787336005066,
#     'MSE': 3.484357209532676,
#     'R2': 0.5836709766797807,
#     'NRMSE': 0.6452356339510547,
#     'MAPE': 1.4317614743642337},
#    'Tts_c_b': {'RMSE': 2.469968970648892,
#     'MAE': 2.110447447060472,
#     'MSE': 6.100746715968349,
#     'R2': 0.5125204522611205,
#     'NRMSE': 0.6981973558664337,
#     'MAPE': 2.5612781244188016}},
#   'elapsed_time': 1.852783203125,
#   'average_elapsed_time': 0.0014025610924489024,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20230630',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 287933394.4482684,
#    'ISE': 206166.00381732365,
#    'IAE': 71143.4824364395,
#    'RMSE': 2.0827775826545443,
#    'MAE': 1.4969381483070214,
#    'MSE': 4.337962458808308,
#    'R2': 0.8462168234079335,
#    'NRMSE': 0.39215198149705494,
#    'MAPE': 1.6881651423328006},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.5059055229775042,
#     'MAE': 0.9862666149366771,
#     'MSE': 2.2677514441341504,
#     'R2': 0.14005404997867976,
#     'NRMSE': 0.9273327072962111,
#     'MAPE': 1.029430334666623},
#    'Tts_h_m': {'RMSE': 1.2164794704446,
#     'MAE': 0.974221913619963,
#     'MSE': 1.4798223020131747,
#     'R2': 0.7927743176326807,
#     'NRMSE': 0.4552204766564432,
#     'MAPE': 1.0413016067540228},
#    'Tts_h_b': {'RMSE': 2.8223319114449166,
#     'MAE': 1.9561713340715523,
#     'MSE': 7.9655574183603175,
#     'R2': 0.6162594922128919,
#     'NRMSE': 0.6194679231300908,
#     'MAPE': 2.169628192429584},
#    'Tts_c_t': {'RMSE': 2.175422978316825,
#     'MAE': 1.7055460076744098,
#     'MSE': 4.732465134588846,
#     'R2': -0.5772679115092694,
#     'NRMSE': 1.2558932723401577,
#     'MAPE': 1.8969178695729518},
#    'Tts_c_m': {'RMSE': 1.868304126927771,
#     'MAE': 1.2490083391778133,
#     'MSE': 3.49056031069534,
#     'R2': 0.5829297980653886,
#     'NRMSE': 0.6458097257974762,
#     'MAPE': 1.430237943695827},
#    'Tts_c_b': {'RMSE': 2.4681203664039595,
#     'MAE': 2.110414680361714,
#     'MSE': 6.091618143058015,
#     'R2': 0.5132498699539061,
#     'NRMSE': 0.6976748025019206,
#     'MAPE': 2.561474906877794}},
#   'elapsed_time': 1.2248539924621582,
#   'average_elapsed_time': 0.0009272172539456155,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20230630',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 291325098.87488836,
#    'ISE': 206624.89171224379,
#    'IAE': 71491.22223118016,
#    'RMSE': 2.085094235633819,
#    'MAE': 1.504254981087829,
#    'MSE': 4.347617971473379,
#    'R2': 0.8458745301254629,
#    'NRMSE': 0.3925881682813902,
#    'MAPE': 1.6959337058000976},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.4571406679647654,
#     'MAE': 1.059752977184033,
#     'MSE': 2.1232589262368027,
#     'R2': 0.19484654317523864,
#     'NRMSE': 0.8973034363161445,
#     'MAPE': 1.105304365740459},
#    'Tts_h_m': {'RMSE': 1.2172686647176911,
#     'MAE': 0.9795800624195038,
#     'MSE': 1.4817430021035907,
#     'R2': 0.7925053539967644,
#     'NRMSE': 0.4555158021443775,
#     'MAPE': 1.0442004372097433},
#    'Tts_h_b': {'RMSE': 2.6797410649361386,
#     'MAE': 1.9163959370315704,
#     'MSE': 7.181012175105071,
#     'R2': 0.6540549375554605,
#     'NRMSE': 0.5881709466171714,
#     'MAPE': 2.1212470065848823},
#    'Tts_c_t': {'RMSE': 2.0834998707213885,
#     'MAE': 1.6073370369846902,
#     'MSE': 4.340971711296043,
#     'R2': -0.44678834186310024,
#     'NRMSE': 1.2028251501623584,
#     'MAPE': 1.7886241929851092},
#    'Tts_c_m': {'RMSE': 1.870998307949087,
#     'MAE': 1.2466151002515375,
#     'MSE': 3.500634668348347,
#     'R2': 0.5817260617002478,
#     'NRMSE': 0.6467410133119379,
#     'MAPE': 1.4291237632670835},
#    'Tts_c_b': {'RMSE': 2.7309498980666813,
#     'MAE': 2.2158487726556384,
#     'MSE': 7.4580873457504175,
#     'R2': 0.4040622868693545,
#     'NRMSE': 0.7719700208755814,
#     'MAPE': 2.6871024690133085}},
#   'elapsed_time': 0.14260196685791016,
#   'average_elapsed_time': 0.0014260196685791015,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20230630',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 292078279.0034427,
#    'ISE': 207176.21895446058,
#    'IAE': 71703.91423709839,
#    'RMSE': 2.0878741607228615,
#    'MAE': 1.5087302579030086,
#    'MSE': 4.359218511014194,
#    'R2': 0.8454632845608209,
#    'NRMSE': 0.39311158141064617,
#    'MAPE': 1.7007419920201792},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.4710136322698788,
#     'MAE': 1.068207706611504,
#     'MSE': 2.163881106323822,
#     'R2': 0.17944235091368033,
#     'NRMSE': 0.9058463716802755,
#     'MAPE': 1.1141119733251863},
#    'Tts_h_m': {'RMSE': 1.227053232115118,
#     'MAE': 0.9885242240765275,
#     'MSE': 1.5056596344441577,
#     'R2': 0.78915620832572,
#     'NRMSE': 0.4591772987357715,
#     'MAPE': 1.0537523781251696},
#    'Tts_h_b': {'RMSE': 2.685553163516672,
#     'MAE': 1.9308135230241028,
#     'MSE': 7.212195794074405,
#     'R2': 0.6525526675761681,
#     'NRMSE': 0.5894466323797531,
#     'MAPE': 2.137015065259165},
#    'Tts_c_t': {'RMSE': 2.082158841422244,
#     'MAE': 1.604675023577626,
#     'MSE': 4.335385440912821,
#     'R2': -0.4449265119774297,
#     'NRMSE': 1.2020509606407832,
#     'MAPE': 1.7856772353619783},
#    'Tts_c_m': {'RMSE': 1.8707334782142662,
#     'MAE': 1.2445641193814907,
#     'MSE': 3.4996437465116466,
#     'R2': 0.5818444621671492,
#     'NRMSE': 0.6466494706043227,
#     'MAPE': 1.4267675246457654},
#    'Tts_c_b': {'RMSE': 2.727369674946597,
#     'MAE': 2.2155969507468005,
#     'MSE': 7.438545343818307,
#     'R2': 0.40562378855222925,
#     'NRMSE': 0.7709579829327736,
#     'MAPE': 2.6871277754038108}},
#   'elapsed_time': 0.09086751937866211,
#   'average_elapsed_time': 0.0009086751937866211,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20230630',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 286108314.7494311,
#    'ISE': 252988.016114035,
#    'IAE': 73168.53739926814,
#    'RMSE': 2.3071952178026196,
#    'MAE': 1.5395475613194491,
#    'MSE': 5.323149773051277,
#    'R2': 0.8112913863712767,
#    'NRMSE': 0.4344060469522994,
#    'MAPE': 1.7299595463891728},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.4905573743813851,
#     'MAE': 1.0820685230712617,
#     'MSE': 2.2217612863227285,
#     'R2': 0.1574938139585783,
#     'NRMSE': 0.9178813572795897,
#     'MAPE': 1.1286504718092638},
#    'Tts_h_m': {'RMSE': 1.3480210750543908,
#     'MAE': 1.080705392232566,
#     'MSE': 1.8171608187907955,
#     'R2': 0.7455353996673806,
#     'NRMSE': 0.5044448436971276,
#     'MAPE': 1.1503984249940218},
#    'Tts_h_b': {'RMSE': 2.997619892523531,
#     'MAE': 2.2180445922698544,
#     'MSE': 8.985725020052785,
#     'R2': 0.567112946285161,
#     'NRMSE': 0.6579415275804067,
#     'MAPE': 2.451663547736057},
#    'Tts_c_t': {'RMSE': 2.0732763989862693,
#     'MAE': 1.4762731270916176,
#     'MSE': 4.298475026593471,
#     'R2': -0.43262476004672457,
#     'NRMSE': 1.1969230384810565,
#     'MAPE': 1.6450706695514135},
#    'Tts_c_m': {'RMSE': 2.2471814147550235,
#     'MAE': 1.2425113452399874,
#     'MSE': 5.049824310820388,
#     'R2': 0.39662086955070663,
#     'NRMSE': 0.7767748260913798,
#     'MAPE': 1.4158011338885013},
#    'Tts_c_b': {'RMSE': 3.092887352576471,
#     'MAE': 2.1376823880114078,
#     'MSE': 9.56595217572749,
#     'R2': 0.2356335613622973,
#     'NRMSE': 0.8742805262830133,
#     'MAPE': 2.588173030355779}},
#   'elapsed_time': 0.0561981201171875,
#   'average_elapsed_time': 0.0014049530029296875,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20230630',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 286788223.8239305,
#    'ISE': 252328.9279543133,
#    'IAE': 73254.19836577197,
#    'RMSE': 2.3041878881124553,
#    'MAE': 1.5413499635099097,
#    'MSE': 5.309281823724136,
#    'R2': 0.8117830128711823,
#    'NRMSE': 0.4338398173621433,
#    'MAPE': 1.7318994831462475},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 1.495321021331981,
#     'MAE': 1.0853109704619228,
#     'MSE': 2.2359849568373185,
#     'R2': 0.15210010651101036,
#     'NRMSE': 0.9208147986913491,
#     'MAPE': 1.1320079824201112},
#    'Tts_h_m': {'RMSE': 1.352047283105882,
#     'MAE': 1.084474680904639,
#     'MSE': 1.8280318557539974,
#     'R2': 0.7440130830691815,
#     'NRMSE': 0.5059514966188148,
#     'MAPE': 1.1543315225151638},
#    'Tts_h_b': {'RMSE': 2.9832221294001138,
#     'MAE': 2.2194971535875125,
#     'MSE': 8.899614273342548,
#     'R2': 0.5712613291205351,
#     'NRMSE': 0.6547813916716517,
#     'MAPE': 2.4529200839011462},
#    'Tts_c_t': {'RMSE': 2.07361285895338,
#     'MAE': 1.4757845483756398,
#     'MSE': 4.299870288816812,
#     'R2': -0.43308978245479945,
#     'NRMSE': 1.1971172801587984,
#     'MAPE': 1.6445232638973863},
#    'Tts_c_m': {'RMSE': 2.2456685845576065,
#     'MAE': 1.242624055688373,
#     'MSE': 5.043027391668963,
#     'R2': 0.3974330006101048,
#     'NRMSE': 0.7762518917142136,
#     'MAPE': 1.415991743022962},
#    'Tts_c_b': {'RMSE': 3.090171868347322,
#     'MAE': 2.1404083720413722,
#     'MSE': 9.549162175925177,
#     'R2': 0.23697516459403678,
#     'NRMSE': 0.873512928013068,
#     'MAPE': 2.5916223031207153}},
#   'elapsed_time': 0.0357050895690918,
#   'average_elapsed_time': 0.0008926272392272949,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20230703',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 587086888.6526073,
#    'ISE': 781770.9543028763,
#    'IAE': 143758.7296028561,
#    'RMSE': 4.055777611649472,
#    'MAE': 3.024843866575266,
#    'MSE': 16.4493320351571,
#    'R2': 0.4696102457865383,
#    'NRMSE': 0.7282786240261769,
#    'MAPE': 3.4510682024436017},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 3.1251196866433717,
#     'MAE': 2.7291248133921924,
#     'MSE': 9.766373055845966,
#     'R2': -6.5984236056771275,
#     'NRMSE': 2.756523826430152,
#     'MAPE': 2.9335032959302967},
#    'Tts_h_m': {'RMSE': 2.5454689476187284,
#     'MAE': 1.8776784616878923,
#     'MSE': 6.479412163291197,
#     'R2': -0.4328929453391308,
#     'NRMSE': 1.1970350643732752,
#     'MAPE': 2.060598161079439},
#    'Tts_h_b': {'RMSE': 6.055712690021302,
#     'MAE': 4.402544297217752,
#     'MSE': 36.67165618408503,
#     'R2': -0.8951726884072939,
#     'NRMSE': 1.3766527116187635,
#     'MAPE': 4.946880711967275},
#    'Tts_c_t': {'RMSE': 4.515913171073774,
#     'MAE': 3.3133469699658074,
#     'MSE': 20.393471768677593,
#     'R2': -0.036206437210404285,
#     'NRMSE': 1.0179422563242004,
#     'MAPE': 3.7112925801985623},
#    'Tts_c_m': {'RMSE': 4.01426737054349,
#     'MAE': 3.245245603583508,
#     'MSE': 16.11434252221015,
#     'R2': 0.4102185387510998,
#     'NRMSE': 0.7679723050012287,
#     'MAPE': 3.88654284945927},
#    'Tts_c_b': {'RMSE': 3.0447884190584795,
#     'MAE': 2.5811230536044407,
#     'MSE': 9.270736516832635,
#     'R2': -0.11971496146541849,
#     'NRMSE': 1.0581658478071472,
#     'MAPE': 3.1675916160267716}},
#   'elapsed_time': 9.750282764434814,
#   'average_elapsed_time': 0.0012309408868116166,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20230703',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 587328758.804121,
#    'ISE': 785572.8219106438,
#    'IAE': 144109.7474449728,
#    'RMSE': 4.0656275734734795,
#    'MAE': 3.0322296731257166,
#    'MSE': 16.529327566187852,
#    'R2': 0.46703088208040766,
#    'NRMSE': 0.7300473395058654,
#    'MAPE': 3.4584584497641875},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 3.1494431945980508,
#     'MAE': 2.753134966382039,
#     'MSE': 9.918992435999977,
#     'R2': -6.717164380191355,
#     'NRMSE': 2.777978470073401,
#     'MAPE': 2.9591535028708416},
#    'Tts_h_m': {'RMSE': 2.5848702119164613,
#     'MAE': 1.907935610169057,
#     'MSE': 6.68155401245305,
#     'R2': -0.47759570884950153,
#     'NRMSE': 1.2155639468368178,
#     'MAPE': 2.09351148252632},
#    'Tts_h_b': {'RMSE': 6.067058345496372,
#     'MAE': 4.407605986054382,
#     'MSE': 36.80919696765718,
#     'R2': -0.9022807267042174,
#     'NRMSE': 1.3792319336153065,
#     'MAPE': 4.952240949770948},
#    'Tts_c_t': {'RMSE': 4.531907038322776,
#     'MAE': 3.3172556500742565,
# ...
#     'MAPE': 1.6183769611189311},
#    'Tts_c_t': {'RMSE': 1.5104741753704802,
#     'MAE': 1.0236092089213515,
#     'MSE': 2.281532234461132,
#     'R2': 0.7867468218304603,
#     'NRMSE': 0.4617934366895438,
#     'MAPE': 1.1354833478776283},
#    'Tts_c_m': {'RMSE': 1.7400189867546318,
#     'MAE': 1.0569449187083626,
#     'MSE': 3.0276660742666155,
#     'R2': 0.7367834832982822,
#     'NRMSE': 0.5130463104844608,
#     'MAPE': 1.1766158426296858},
#    'Tts_c_b': {'RMSE': 2.9154034578675256,
#     'MAE': 2.0442386833505544,
#     'MSE': 8.499577322145925,
#     'R2': 0.8536676662186985,
#     'NRMSE': 0.382534094926585,
#     'MAPE': 2.4136965775406853}},
#   'elapsed_time': 0.028562307357788086,
#   'average_elapsed_time': 0.0007719542529131915,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20231031',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 478681156.24626565,
#    'ISE': 857657.3732817281,
#    'IAE': 126841.43259437646,
#    'RMSE': 4.455381345507002,
#    'MAE': 2.9357365318329967,
#    'MSE': 19.850422933891778,
#    'R2': 0.598750378759616,
#    'NRMSE': 0.6334426739969324,
#    'MAPE': 3.900099683781489},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.88847470820812,
#     'MAE': 6.9375771916007105,
#     'MSE': 62.22803322203918,
#     'R2': -2.1276446531976108,
#     'NRMSE': 1.7685148156568018,
#     'MAPE': 8.68894185100779},
#    'Tts_h_m': {'RMSE': 4.269383193180826,
#     'MAE': 2.4588359609490764,
#     'MSE': 18.22763285021491,
#     'R2': 0.6906277914995185,
#     'NRMSE': 0.5562123771550589,
#     'MAPE': 3.1439938293444922},
#    'Tts_h_b': {'RMSE': 4.716094661311344,
#     'MAE': 2.491290114436224,
#     'MSE': 22.241548854449366,
#     'R2': -0.27383871265389637,
#     'NRMSE': 1.1286446352390536,
#     'MAPE': 3.2700977820668027},
#    'Tts_c_t': {'RMSE': 2.7283776062837983,
#     'MAE': 2.2419876405298367,
#     'MSE': 7.444044362470908,
#     'R2': 0.805148530273821,
#     'NRMSE': 0.4414198338613467,
#     'MAPE': 3.1789394388347985},
#    'Tts_c_m': {'RMSE': 2.3526904968641653,
#     'MAE': 1.8783701844726888,
#     'MSE': 5.535152574034953,
#     'R2': 0.8253451992795253,
#     'NRMSE': 0.417917217544904,
#     'MAPE': 2.7127340422292487},
#    'Tts_c_b': {'RMSE': 1.8509796703749417,
#     'MAE': 1.606358099009446,
#     'MSE': 3.4261257401413276,
#     'R2': -0.0905095588623519,
#     'NRMSE': 1.0442746568132122,
#     'MAPE': 2.4058911592058028}},
#   'elapsed_time': 8.911731004714966,
#   'average_elapsed_time': 0.0012375685328030782,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231031',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 483828371.40760756,
#    'ISE': 879090.0013289447,
#    'IAE': 128310.26196507849,
#    'RMSE': 4.510707226850544,
#    'MAE': 2.9697324900494952,
#    'MSE': 20.346479686361725,
#    'R2': 0.5887232581937129,
#    'NRMSE': 0.6413086166630595,
#    'MAPE': 3.943260568560278},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 8.027616843473085,
#     'MAE': 7.064038130156133,
#     'MSE': 64.4426321856128,
#     'R2': -2.2389526642138557,
#     'NRMSE': 1.7997090498783006,
#     'MAPE': 8.843754132664564},
#    'Tts_h_m': {'RMSE': 4.345627997858793,
#     'MAE': 2.5064595424573315,
#     'MSE': 18.884482695774224,
#     'R2': 0.6794792738042277,
#     'NRMSE': 0.5661454991393753,
#     'MAPE': 3.2044998433734726},
#    'Tts_h_b': {'RMSE': 4.724245844104752,
#     'MAE': 2.5147444565793147,
#     'MSE': 22.318498795541018,
#     'R2': -0.2782458613889258,
#     'NRMSE': 1.1305953570526133,
#     'MAPE': 3.304353683731198},
#    'Tts_c_t': {'RMSE': 2.728523666097336,
#     'MAE': 2.241476421454346,
#     'MSE': 7.444841396453247,
#     'R2': 0.805127667522967,
#     'NRMSE': 0.44144346464415224,
#     'MAPE': 3.1781684800949415},
#    'Tts_c_m': {'RMSE': 2.352782714389826,
#     'MAE': 1.8784078085480582,
#     'MSE': 5.535586501131556,
#     'R2': 0.8253315072539541,
#     'NRMSE': 0.4179335984890972,
#     'MAPE': 2.712750159265415},
#    'Tts_c_b': {'RMSE': 1.858180977100334,
#     'MAE': 1.6132685811017888,
#     'MSE': 3.452836543657552,
#     'R2': -0.09901140286009569,
#     'NRMSE': 1.0483374470370195,
#     'MAPE': 2.416037112232077}},
#   'elapsed_time': 5.746992349624634,
#   'average_elapsed_time': 0.0007980825370954914,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 5},
#  {'test_id': '20231031',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 477993888.1431703,
#    'ISE': 855323.7492726307,
#    'IAE': 126729.19377139997,
#    'RMSE': 4.449315830688403,
#    'MAE': 2.9331387717307775,
#    'MSE': 19.79641136121443,
#    'R2': 0.599842150111368,
#    'NRMSE': 0.6325803110187923,
#    'MAPE': 3.896359293402771},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.875175971235414,
#     'MAE': 6.928804991003014,
#     'MSE': 62.01839657792365,
#     'R2': -2.1171081008572425,
#     'NRMSE': 1.7655333757415186,
#     'MAPE': 8.677214561476815},
#    'Tts_h_m': {'RMSE': 4.262326117267991,
#     'MAE': 2.4566119753757607,
#     'MSE': 18.167423929944825,
#     'R2': 0.6916496996533886,
#     'NRMSE': 0.5552929860412532,
#     'MAPE': 3.1408352467774305},
#    'Tts_h_b': {'RMSE': 4.707904197010283,
#     'MAE': 2.4868354567817694,
#     'MSE': 22.164361928227038,
#     'R2': -0.2694179910856189,
#     'NRMSE': 1.1266845126678626,
#     'MAPE': 3.2640143547061053},
#    'Tts_c_t': {'RMSE': 2.7363114101996033,
#     'MAE': 2.251745057518288,
#     'MSE': 7.487400133588543,
#     'R2': 0.8040136719478856,
#     'NRMSE': 0.442703431263091,
#     'MAPE': 3.192889376181208},
#    'Tts_c_m': {'RMSE': 2.3578499113873925,
#     'MAE': 1.884471995129791,
#     'MSE': 5.559456204629535,
#     'R2': 0.8245783286826438,
#     'NRMSE': 0.4188337036549903,
#     'MAPE': 2.721626460201607},
#    'Tts_c_b': {'RMSE': 1.838866333634122,
#     'MAE': 1.5903631545760397,
#     'MSE': 3.381429392972998,
#     'R2': -0.0762830541949302,
#     'NRMSE': 1.0374406268287986,
#     'MAPE': 2.3815757610734587}},
#   'elapsed_time': 1.469064712524414,
#   'average_elapsed_time': 0.001223201259387522,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231031',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 483158175.12668985,
#    'ISE': 876705.3256149042,
#    'IAE': 128198.84920249495,
#    'RMSE': 4.5045850558475005,
#    'MAE': 2.9671538490601987,
#    'MSE': 20.29128652536463,
#    'R2': 0.5898389137653296,
#    'NRMSE': 0.6404381986067589,
#    'MAPE': 3.939554401433227},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 8.014609092654666,
#     'MAE': 7.055509863614293,
#     'MSE': 64.23395890806285,
#     'R2': -2.228464531663281,
#     'NRMSE': 1.7967928460630296,
#     'MAPE': 8.832368454975267},
#    'Tts_h_m': {'RMSE': 4.338031825837253,
#     'MAE': 2.504258639285018,
#     'MSE': 18.818520121976892,
#     'R2': 0.6805988370136553,
#     'NRMSE': 0.5651558749463236,
#     'MAPE': 3.2014295414786904},
#    'Tts_h_b': {'RMSE': 4.71584419480063,
#     'MAE': 2.510120136612519,
#     'MSE': 22.239186469634806,
#     'R2': -0.2737034119493158,
#     'NRMSE': 1.128584694185295,
#     'MAPE': 3.2980262852081346},
#    'Tts_c_t': {'RMSE': 2.7364523383786032,
#     'MAE': 2.2512662734173885,
#     'MSE': 7.488171400217726,
#     'R2': 0.8039934836699913,
#     'NRMSE': 0.44272623180698095,
#     'MAPE': 3.192158239951695},
#    'Tts_c_m': {'RMSE': 2.357936747556778,
#     'MAE': 1.8845054851255942,
#     'MSE': 5.559865705478637,
#     'R2': 0.8245654073966922,
#     'NRMSE': 0.41884912868872937,
#     'MAPE': 2.721636926961651},
#    'Tts_c_b': {'RMSE': 1.846081403085163,
#     'MAE': 1.5972626963063787,
#     'MSE': 3.408016546816884,
#     'R2': -0.08474554144985103,
#     'NRMSE': 1.0415111816249747,
#     'MAPE': 2.391706960023924}},
#   'elapsed_time': 0.8866391181945801,
#   'average_elapsed_time': 0.0007382507228930725,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 30},
#  {'test_id': '20231031',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 475095616.39247507,
#    'ISE': 857652.4390068301,
#    'IAE': 127473.16522412341,
#    'RMSE': 4.455368529137296,
#    'MAE': 2.950357941585044,
#    'MSE': 19.850308730427027,
#    'R2': 0.59875268722917,
#    'NRMSE': 0.6334408518329316,
#    'MAPE': 3.916246823041248},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.766387562795824,
#     'MAE': 6.861043008779344,
#     'MSE': 60.31677577554966,
#     'R2': -2.0315828973637475,
#     'NRMSE': 1.7411441345746619,
#     'MAPE': 8.582553588639387},
#    'Tts_h_m': {'RMSE': 4.283162410558525,
#     'MAE': 2.47940580616529,
#     'MSE': 18.345480235221515,
#     'R2': 0.6886276027714978,
#     'NRMSE': 0.5580075243475684,
#     'MAPE': 3.1642541703932636},
#    'Tts_h_b': {'RMSE': 4.761556279454505,
#     'MAE': 2.53235854786187,
#     'MSE': 22.672418202412636,
#     'R2': -0.2985158634729932,
#     'NRMSE': 1.1395244023157174,
#     'MAPE': 3.32559078109954},
#    'Tts_c_t': {'RMSE': 2.845675233761999,
#     'MAE': 2.3626753834942127,
#     'MSE': 8.097867536046408,
#     'R2': 0.7880343917613615,
#     'NRMSE': 0.460397228747783,
#     'MAPE': 3.346914431103172},
#    'Tts_c_m': {'RMSE': 2.4162670777851107,
#     'MAE': 1.9377196057062167,
#     'MSE': 5.8383465911881975,
#     'R2': 0.8157782921460264,
#     'NRMSE': 0.4292105635395914,
#     'MAPE': 2.793313164910888},
#    'Tts_c_b': {'RMSE': 1.9572848648430714,
#     'MAE': 1.5289452975033315,
#     'MSE': 3.8309640421437603,
#     'R2': -0.21936648695310113,
#     'NRMSE': 1.1042492865984117,
#     'MAPE': 2.284854802101236}},
#   'elapsed_time': 0.11020922660827637,
#   'average_elapsed_time': 0.0012110904022887513,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231031',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 480506318.6328285,
#    'ISE': 879212.0729594094,
#    'IAE': 128975.47287300222,
#    'RMSE': 4.511020397442258,
#    'MAE': 2.985128752326117,
#    'MSE': 20.349305026140108,
#    'R2': 0.5886661477472641,
#    'NRMSE': 0.6413531416097811,
#    'MAPE': 3.96051035033907},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.910365890052165,
#     'MAE': 6.991238568097356,
#     'MSE': 62.57388851450078,
#     'R2': -2.1450276942522413,
#     'NRMSE': 1.7734225932507575,
#     'MAPE': 8.742352580652804},
#    'Tts_h_m': {'RMSE': 4.3561847001401395,
#     'MAE': 2.528305501164892,
#     'MSE': 18.976345141735038,
#     'R2': 0.6779201197429905,
#     'NRMSE': 0.5675208192278143,
#     'MAPE': 3.226949991403928},
#    'Tts_h_b': {'RMSE': 4.76967467921659,
#     'MAE': 2.5554830547646956,
#     'MSE': 22.749796545559878,
#     'R2': -0.30294754804977364,
#     'NRMSE': 1.1414672785716522,
#     'MAPE': 3.3593434677243614},
#    'Tts_c_t': {'RMSE': 2.845772033761615,
#     'MAE': 2.3621928941969075,
#     'MSE': 8.098418468139718,
#     'R2': 0.788019970846752,
#     'NRMSE': 0.4604128898643564,
#     'MAPE': 3.346166534611309},
#    'Tts_c_m': {'RMSE': 2.4163451440758164,
#     'MAE': 1.9377222906934184,
#     'MSE': 5.838723855298778,
#     'R2': 0.8157663880499475,
#     'NRMSE': 0.4292244307469607,
#     'MAPE': 2.793278897531968},
#    'Tts_c_b': {'RMSE': 1.9643466169712587,
#     'MAE': 1.5358302050394343,
#     'MSE': 3.8586576316064285,
#     'R2': -0.22818114418369184,
#     'NRMSE': 1.1082333437429557,
#     'MAPE': 2.294970630110055}},
#   'elapsed_time': 0.06609678268432617,
#   'average_elapsed_time': 0.0007263382712563315,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 400},
#  {'test_id': '20231031',
#   'alternative': 'standard',
#   'metrics': {'ITAE': 490063267.0582945,
#    'ISE': 917728.4331497008,
#    'IAE': 133842.62820108348,
#    'RMSE': 4.608770294152033,
#    'MAE': 3.097778739089096,
#    'MSE': 21.24076362425822,
#    'R2': 0.5706465102797087,
#    'NRMSE': 0.6552507075313168,
#    'MAPE': 4.121329114274235},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.651067107271017,
#     'MAE': 6.780770214155465,
#     'MSE': 58.53882787996449,
#     'R2': -1.9422214160286528,
#     'NRMSE': 1.7152904757004435,
#     'MAPE': 8.46775194757077},
#    'Tts_h_m': {'RMSE': 4.377181905630955,
#     'MAE': 2.520547469155479,
#     'MSE': 19.15972143498304,
#     'R2': 0.674807728282456,
#     'NRMSE': 0.5702563210675915,
#     'MAPE': 3.200032983205267},
#    'Tts_h_b': {'RMSE': 4.93823182579402,
#     'MAE': 2.7414869356978606,
#     'MSE': 24.38613356528494,
#     'R2': -0.39666536672846253,
#     'NRMSE': 1.1818059767696483,
#     'MAPE': 3.617875667879331},
#    'Tts_c_t': {'RMSE': 3.01517022206717,
#     'MAE': 2.522505759712103,
#     'MSE': 9.091251468040587,
#     'R2': 0.7620320857934821,
#     'NRMSE': 0.4878195508653972,
#     'MAPE': 3.567237133413793},
#    'Tts_c_m': {'RMSE': 2.5064758589525615,
#     'MAE': 2.0151212821628253,
#     'MSE': 6.282421231511981,
#     'R2': 0.801766073553427,
#     'NRMSE': 0.44523468693103074,
#     'MAPE': 2.892459088993613},
#    'Tts_c_b': {'RMSE': 3.160099075308292,
#     'MAE': 2.006240773650842,
#     'MSE': 9.986226165764322,
#     'R2': -2.178539235480047,
#     'NRMSE': 1.7828458249327246,
#     'MAPE': 2.9826178645826382}},
#   'elapsed_time': 0.04418516159057617,
#   'average_elapsed_time': 0.0011941935565020587,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000},
#  {'test_id': '20231031',
#   'alternative': 'constant-water-props',
#   'metrics': {'ITAE': 495752459.54521555,
#    'ISE': 939452.2786409649,
#    'IAE': 135380.12011853102,
#    'RMSE': 4.662999097697345,
#    'MAE': 3.1333638873890437,
#    'MSE': 21.743560585126254,
#    'R2': 0.5604831454596746,
#    'NRMSE': 0.6629606734492819,
#    'MAPE': 4.166815132875481},
#   'metrics_per_variable': {'Tts_h_t': {'RMSE': 7.797640442153175,
#     'MAE': 6.9125602591991155,
#     'MSE': 60.803196465102765,
#     'R2': -2.056030899174395,
#     'NRMSE': 1.7481507083699608,
#     'MAPE': 8.629841645592084},
#    'Tts_h_m': {'RMSE': 4.447194175809149,
#     'MAE': 2.5707463149942695,
#     'MSE': 19.777536037350817,
#     'R2': 0.6643217441972481,
#     'NRMSE': 0.5793774726400327,
#     'MAPE': 3.264804646569413},
#    'Tts_h_b': {'RMSE': 4.947944458817886,
#     'MAE': 2.767126581578688,
#     'MSE': 24.482154367546617,
#     'R2': -0.4021647595963538,
#     'NRMSE': 1.1841303811643182,
#     'MAPE': 3.655352898416649},
#    'Tts_c_t': {'RMSE': 3.0151828136988215,
#     'MAE': 2.5221462904541228,
#     'MSE': 9.091327400024742,
#     'R2': 0.7620300982369884,
#     'NRMSE': 0.4878215880452725,
#     'MAPE': 3.5666389516118704},
#    'Tts_c_m': {'RMSE': 2.5065711163648516,
#     'MAE': 2.0151257142143493,
#     'MSE': 6.282898761394539,
#     'R2': 0.8017510056966045,
#     'NRMSE': 0.44525160786166224,
#     'MAPE': 2.8924301923891216},
#    'Tts_c_b': {'RMSE': 3.1661096758226885,
#     'MAE': 2.0124781638937184,
#     'MSE': 10.02425047933805,
#     'R2': -2.19064208300123,
#     'NRMSE': 1.7862368496370324,
#     'MAPE': 2.9918224626737477}},
#   'elapsed_time': 0.02662491798400879,
#   'average_elapsed_time': 0.0007195923779461835,
#   'model_parameters': {'UA_h': [0.0069818, 0.00584034, 0.03041486],
#    'V_h': [5.94771006, 4.87661781, 2.19737023],
#    'UA_c': [0.01396848, 0.0001, 0.02286885],
#    'V_c': [5.33410037, 7.56470594, 0.90547187]},
#   'sample_rate': 1000}]

# %%
# Parse results dict into compatible format for latex table

table_data = parse_benchmark_results_to_latex_data(
    selected_alternatives=selected_alternatives,
    selected_sample_times=selected_sample_times,
    out_var_ids=out_var_ids,
    stats=stats,
    out_vars_dict=out_vars_dict,
    filter_out_tests=filter_out_tests
)
# Out:
# 2025-08-30 07:49:58.516 | INFO     | __main__:parse_benchmark_results_to_latex_data:102 - Processing alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.517 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.518 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.518 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.519 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.519 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.520 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.520 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.521 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.522 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.523 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.523 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231031 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.524 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.525 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.525 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.526 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.526 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.517 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.518 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.518 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.519 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.519 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.520 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.520 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.521 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.522 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.523 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.523 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231031 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.524 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.525 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.525 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.526 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.526 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.527 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.528 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.528 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.529 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.529 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-08-30 07:49:58.530 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231031 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.531 | INFO     | __main__:parse_benchmark_results_to_latex_data:102 - Processing alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.531 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.532 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.532 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.533 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.533 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230508, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.534 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230707, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.534 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230628, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.535 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230511, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.536 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230629, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.536 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20230505, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.537 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231031 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.537 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231030 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.538 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231106 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.538 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.539 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20230703 as it is in the filter_out_tests list
# 2025-08-30 07:49:58.540 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230508, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.540 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230707, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.541 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230628, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.541 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230511, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.542 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230629, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.542 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20230505, alternative: constant-water-props, sample time: 400 s
# 2025-08-30 07:49:58.543 | WARNING  | __main__:parse_benchmark_results_to_latex_data:109 - Skipping test id: 20231031 as it is in the filter_out_tests list

# %%
table_str = generate_latex_table(
    regular_col_ids,
    regular_col_labels,
    metric_info,
    table_data,
    submetric_ids,
    group_row_ids,
    submetric_labels,
    group_submetric_ids
)

print(table_str)
# Out:
# \begin{tabular}{ccccccccccccccccccccc}
# \hline
# \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Predicted\\ variable\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Sample\\ time\\ (s)\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Test\\ date\end{tabular}}} &  & \multicolumn{15}{c}{\textbf{Performance metric}}
# \\\cline{7-21}
#  &  &  &  &  &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}R$^2$\\ (-)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAE\\ (s.u.)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAPE\\ (\%)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}Time\\ (s)\end{tabular}}}
#  \\\cline{7-9}\cline{11-13}\cline{15-17}\cline{19-21}
#  &  &  &  &  &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg.
#  \\\cline{1-1}\cline{3-3}\cline{5-5}\cline{7-7}\cline{9-9}\cline{11-11}\cline{13-13}\cline{15-15}\cline{17-17}\cline{19-19}\cline{21-21}
# \multirow{7}{*}{T$_{ts,h}$ ($^\circ$C)} &  & \multirow{14}{*}{5} &  & 20230630 &  & 0.13 &  & \multirow{7}{*}{0.51} &  & 0.99 &  & \multirow{7}{*}{1.14} &  & 1.03 &  & \multirow{7}{*}{1.15} &  & 5.91 &  & \multirow{14}{*}{5.35} \\
#  &  &  &  & 20230508 &  & 0.79 &  &  &  & 1.47 &  &  &  & 1.58 &  &  &  & 5.36 &  &  \\
#  &  &  &  & 20230707 &  & 0.88 &  &  &  & 1.11 &  &  &  & 1.27 &  &  &  & 55.49 &  &  \\
#  &  &  &  & 20230628 &  & 0.76 &  &  &  & 1.02 &  &  &  & 1.16 &  &  &  & 5.89 &  &  \\
#  &  &  &  & 20230511 &  & 0.22 &  &  &  & 2.26 &  &  &  & 2.52 &  &  &  & 5.28 &  &  \\
#  &  &  &  & 20230629 &  & 0.98 &  &  &  & 0.34 &  &  &  & 0.36 &  &  &  & 5.84 &  &  \\
#  &  &  &  & 20230505 &  & 0.51 &  &  &  & 1.14 &  &  &  & 1.15 &  &  &  & 5.35 &  &  \\
# \multirow{7}{*}{T$_{ts,c}$ ($^\circ$C)} &  &  &  & 20230630 &  & 0.52 &  & \multirow{7}{*}{0.88} &  & 2.11 &  & \multirow{7}{*}{1.78} &  & 2.56 &  & \multirow{7}{*}{2.14} &  & 5.91 &  &  \\
#  &  &  &  & 20230508 &  & 0.83 &  &  &  & 1.05 &  &  &  & 1.37 &  &  &  & 5.36 &  &  \\
#  &  &  &  & 20230707 &  & 0.87 &  &  &  & 3.15 &  &  &  & 4.35 &  &  &  & 55.49 &  &  \\
#  &  &  &  & 20230628 &  & 0.68 &  &  &  & 2.86 &  &  &  & 3.78 &  &  &  & 5.89 &  &  \\
#  &  &  &  & 20230511 &  & 0.96 &  &  &  & 1.75 &  &  &  & 2.17 &  &  &  & 5.28 &  &  \\
#  &  &  &  & 20230629 &  & 0.88 &  &  &  & 2.02 &  &  &  & 2.52 &  &  &  & 5.84 &  &  \\
#  &  &  &  & 20230505 &  & 0.88 &  &  &  & 1.78 &  &  &  & 2.14 &  &  &  & 5.35 &  &  \\
# \multirow{7}{*}{T$_{ts,h}$ ($^\circ$C)} &  & \multirow{14}{*}{400} &  & 20230630 &  & 0.18 &  & \multirow{7}{*}{0.54} &  & 1.07 &  & \multirow{7}{*}{1.14} &  & 1.11 &  & \multirow{7}{*}{1.14} &  & 0.09 &  & \multirow{14}{*}{0.07} \\
#  &  &  &  & 20230508 &  & 0.79 &  &  &  & 1.47 &  &  &  & 1.58 &  &  &  & 0.08 &  &  \\
#  &  &  &  & 20230707 &  & 0.88 &  &  &  & 1.10 &  &  &  & 1.26 &  &  &  & 0.63 &  &  \\
#  &  &  &  & 20230628 &  & 0.76 &  &  &  & 1.03 &  &  &  & 1.18 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230511 &  & 0.21 &  &  &  & 2.33 &  &  &  & 2.59 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230629 &  & 0.98 &  &  &  & 0.36 &  &  &  & 0.38 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230505 &  & 0.54 &  &  &  & 1.14 &  &  &  & 1.14 &  &  &  & 0.07 &  &  \\
# \multirow{7}{*}{T$_{ts,c}$ ($^\circ$C)} &  &  &  & 20230630 &  & 0.41 &  & \multirow{7}{*}{0.84} &  & 2.22 &  & \multirow{7}{*}{2.05} &  & 2.69 &  & \multirow{7}{*}{2.44} &  & 0.09 &  &  \\
#  &  &  &  & 20230508 &  & 0.74 &  &  &  & 1.25 &  &  &  & 1.60 &  &  &  & 0.08 &  &  \\
#  &  &  &  & 20230707 &  & 0.87 &  &  &  & 3.09 &  &  &  & 4.26 &  &  &  & 0.63 &  &  \\
#  &  &  &  & 20230628 &  & 0.68 &  &  &  & 2.81 &  &  &  & 3.73 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230511 &  & 0.94 &  &  &  & 1.89 &  &  &  & 2.40 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230629 &  & 0.88 &  &  &  & 1.97 &  &  &  & 2.47 &  &  &  & 0.07 &  &  \\
#  &  &  &  & 20230505 &  & 0.84 &  &  &  & 2.05 &  &  &  & 2.44 &  &  &  & 0.07 &  &  \\
# \hline
# \end{tabular}

# %% [markdown]
# ### Heat exchanger

# %%
# Load result
from solarmed_modeling.heat_exchanger.benchmark import model_id

out_vars_dict = {
    "Thx_p_out": "T$_{hx,p,out}$ ($^\\circ$C)",
    "Thx_s_out": "T$_{hx,s,out}$ ($^\\circ$C)",
}
out_var_ids = list(out_vars_dict.keys())

# eval_date_str = "20250720"
selected_alternatives: list[str] = ["constant-water-props"]
selected_sample_times: list[int] = [5, 400]

stats = import_benchmark_results(results_path=results_path, model_id=model_id, eval_date_str=eval_date_str)
# stats
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 21
#      14 # # (Some tests just don't make sense, the storage is being discharge and it results in increases in temperature?? 20231106, 20230703, 20231031)
#      15 filter_out_tests = [
#      16     "20231106",
#      17     "20230703",
#      18     "20231031"
#      19 ]
# ---> 21 stats = import_benchmark_results(results_path=results_path, model_id=model_id, eval_date_str=eval_date_str)
#      22 # stats
#
# File /workspaces/SolarMED/modeling/src/solarmed_modeling/benchmark/utils.py:64, in import_benchmark_results(results_path, eval_date_str, model_id)
#      62 if model_id is not None:
#      63     if model_id not in stats:
# ---> 64         raise ValueError(f"Model {model_id} not found in results for {eval_date_str}, available are: {list(stats.keys())}")
#      65     stats = stats[model_id]
#      67 return stats
#
# ValueError: Model heat_exchanger not found in results for 20250829, available are: ['thermal_storage', 'solar_med']

# %%
# Parse results dict into compatible format for latex table

table_data = parse_benchmark_results_to_latex_data(
    selected_alternatives=selected_alternatives,
    selected_sample_times=selected_sample_times,
    out_var_ids=out_var_ids,
    stats=stats,
    out_vars_dict=out_vars_dict,
)
# Out:
# 2025-07-20 17:04:25.965 | INFO     | __main__:parse_benchmark_results_to_latex_data:101 - Processing alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.966 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.967 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.968 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.968 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.969 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.969 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.970 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.971 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.972 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.972 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.973 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231031, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.974 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.975 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.975 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.976 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.966 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.967 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.968 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.968 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.969 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.969 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.970 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.971 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.972 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.972 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.973 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231031, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.974 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231030, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.975 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231106, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.975 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230630, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.976 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230703, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.977 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230508, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.978 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230707, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.979 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230628, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.979 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230511, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.980 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230629, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.980 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230505, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.981 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231031, alternative: constant-water-props, sample time: 5 s
# 2025-07-20 17:04:25.982 | INFO     | __main__:parse_benchmark_results_to_latex_data:101 - Processing alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.982 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.983 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.985 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.985 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230703, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.986 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230508, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.987 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230707, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.988 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230628, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.988 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230511, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.989 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230629, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.989 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20230505, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.991 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_p_out, test id: 20231031, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.992 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.993 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.994 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230630, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.994 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230703, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.995 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230508, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.996 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230707, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.996 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230628, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.997 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230511, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.998 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230629, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.998 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20230505, alternative: constant-water-props, sample time: 400 s
# 2025-07-20 17:04:25.999 | INFO     | __main__:parse_benchmark_results_to_latex_data:129 - Added data for variable: Thx_s_out, test id: 20231031, alternative: constant-water-props, sample time: 400 s

# %%
table_str = generate_latex_table(
    regular_col_ids,
    regular_col_labels,
    metric_info,
    table_data,
    submetric_ids,
    group_row_ids,
    submetric_labels,
    group_submetric_ids
)

print(table_str)
# Out:
# \begin{tabular}{ccccccccccccccccccccc}
# \hline
# \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Predicted\\ variable\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Sample\\ time\\ (s)\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Test\\ date\end{tabular}}} &  & \multicolumn{15}{c}{\textbf{Performance metric}}
# \\\cline{7-21}
#  &  &  &  &  &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}R$^2$\\ (-)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAE\\ (s.u.)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAPE\\ (\%)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}Time\\ (s)\end{tabular}}}
#  \\\cline{7-9}\cline{11-13}\cline{15-17}\cline{19-21}
#  &  &  &  &  &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg.
#  \\\cline{1-1}\cline{3-3}\cline{5-5}\cline{7-7}\cline{9-9}\cline{11-11}\cline{13-13}\cline{15-15}\cline{17-17}\cline{19-19}\cline{21-21}
# \multirow{11}{*}{T$_{hx,p,out}$ ($^\circ$C)} &  & \multirow{22}{*}{5} &  & 20231030 &  & 1.00 &  & \multirow{11}{*}{0.99} &  & 0.86 &  & \multirow{11}{*}{1.08} &  & 1.70 &  & \multirow{11}{*}{3.58} &  & 0.48 &  & \multirow{22}{*}{0.45} \\
#  &  &  &  & 20231106 &  & 1.00 &  &  &  & 1.38 &  &  &  & 3.14 &  &  &  & 0.49 &  &  \\
#  &  &  &  & 20230630 &  & 1.00 &  &  &  & 0.68 &  &  &  & 1.11 &  &  &  & 0.56 &  &  \\
#  &  &  &  & 20230703 &  & 1.00 &  &  &  & 0.53 &  &  &  & 0.67 &  &  &  & 0.60 &  &  \\
#  &  &  &  & 20230508 &  & 0.99 &  &  &  & 1.24 &  &  &  & 1.76 &  &  &  & 0.58 &  &  \\
#  &  &  &  & 20230707 &  & 0.99 &  &  &  & 1.64 &  &  &  & 5.15 &  &  &  & 4.41 &  &  \\
#  &  &  &  & 20230628 &  & 1.00 &  &  &  & 0.73 &  &  &  & 0.93 &  &  &  & 0.58 &  &  \\
#  &  &  &  & 20230511 &  & 0.98 &  &  &  & 1.40 &  &  &  & 1.92 &  &  &  & 0.54 &  &  \\
#  &  &  &  & 20230629 &  & 1.00 &  &  &  & 0.58 &  &  &  & 0.80 &  &  &  & 0.59 &  &  \\
#  &  &  &  & 20230505 &  & 0.99 &  &  &  & 1.22 &  &  &  & 1.67 &  &  &  & 0.54 &  &  \\
#  &  &  &  & 20231031 &  & 0.99 &  &  &  & 1.08 &  &  &  & 3.58 &  &  &  & 0.45 &  &  \\
# \multirow{11}{*}{T$_{hx,s,out}$ ($^\circ$C)} &  &  &  & 20231030 &  & 0.98 &  & \multirow{11}{*}{0.96} &  & 2.58 &  & \multirow{11}{*}{2.16} &  & 5.54 &  & \multirow{11}{*}{7.55} &  & 0.48 &  &  \\
#  &  &  &  & 20231106 &  & 0.97 &  &  &  & 3.19 &  &  &  & 6.88 &  &  &  & 0.49 &  &  \\
#  &  &  &  & 20230630 &  & 0.98 &  &  &  & 2.71 &  &  &  & 4.63 &  &  &  & 0.56 &  &  \\
#  &  &  &  & 20230703 &  & 0.98 &  &  &  & 1.72 &  &  &  & 2.47 &  &  &  & 0.60 &  &  \\
#  &  &  &  & 20230508 &  & 0.96 &  &  &  & 2.57 &  &  &  & 3.70 &  &  &  & 0.58 &  &  \\
#  &  &  &  & 20230707 &  & 0.98 &  &  &  & 2.90 &  &  &  & 7.24 &  &  &  & 4.41 &  &  \\
#  &  &  &  & 20230628 &  & 0.95 &  &  &  & 2.78 &  &  &  & 3.96 &  &  &  & 0.58 &  &  \\
#  &  &  &  & 20230511 &  & 0.95 &  &  &  & 2.88 &  &  &  & 3.95 &  &  &  & 0.54 &  &  \\
#  &  &  &  & 20230629 &  & 0.98 &  &  &  & 2.46 &  &  &  & 4.05 &  &  &  & 0.59 &  &  \\
#  &  &  &  & 20230505 &  & 0.97 &  &  &  & 2.93 &  &  &  & 4.31 &  &  &  & 0.54 &  &  \\
#  &  &  &  & 20231031 &  & 0.96 &  &  &  & 2.16 &  &  &  & 7.55 &  &  &  & 0.45 &  &  \\
# \multirow{11}{*}{T$_{hx,p,out}$ ($^\circ$C)} &  & \multirow{22}{*}{400} &  & 20231030 &  & 1.00 &  & \multirow{11}{*}{0.99} &  & 0.87 &  & \multirow{11}{*}{1.08} &  & 1.74 &  & \multirow{11}{*}{3.60} &  & 0.01 &  & \multirow{22}{*}{0.01} \\
#  &  &  &  & 20231106 &  & 1.00 &  &  &  & 1.39 &  &  &  & 3.17 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230630 &  & 1.00 &  &  &  & 0.70 &  &  &  & 1.16 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230703 &  & 1.00 &  &  &  & 0.55 &  &  &  & 0.70 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230508 &  & 0.99 &  &  &  & 1.26 &  &  &  & 1.82 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230707 &  & 0.99 &  &  &  & 1.63 &  &  &  & 5.14 &  &  &  & 0.06 &  &  \\
#  &  &  &  & 20230628 &  & 1.00 &  &  &  & 0.71 &  &  &  & 0.93 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230511 &  & 0.98 &  &  &  & 1.45 &  &  &  & 2.01 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230629 &  & 1.00 &  &  &  & 0.58 &  &  &  & 0.81 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230505 &  & 0.99 &  &  &  & 1.23 &  &  &  & 1.71 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20231031 &  & 0.99 &  &  &  & 1.08 &  &  &  & 3.60 &  &  &  & 0.01 &  &  \\
# \multirow{11}{*}{T$_{hx,s,out}$ ($^\circ$C)} &  &  &  & 20231030 &  & 0.98 &  & \multirow{11}{*}{0.96} &  & 2.60 &  & \multirow{11}{*}{2.13} &  & 5.64 &  & \multirow{11}{*}{7.46} &  & 0.01 &  &  \\
#  &  &  &  & 20231106 &  & 0.98 &  &  &  & 3.19 &  &  &  & 6.93 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230630 &  & 0.98 &  &  &  & 2.69 &  &  &  & 4.65 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230703 &  & 0.98 &  &  &  & 1.77 &  &  &  & 2.60 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230508 &  & 0.96 &  &  &  & 2.61 &  &  &  & 3.79 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230707 &  & 0.98 &  &  &  & 2.92 &  &  &  & 7.26 &  &  &  & 0.06 &  &  \\
#  &  &  &  & 20230628 &  & 0.95 &  &  &  & 2.77 &  &  &  & 3.98 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230511 &  & 0.95 &  &  &  & 2.84 &  &  &  & 3.90 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230629 &  & 0.98 &  &  &  & 2.52 &  &  &  & 4.19 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20230505 &  & 0.97 &  &  &  & 2.92 &  &  &  & 4.34 &  &  &  & 0.01 &  &  \\
#  &  &  &  & 20231031 &  & 0.96 &  &  &  & 2.13 &  &  &  & 7.46 &  &  &  & 0.01 &  &  \\
# \hline
# \end{tabular}

# %% [markdown]
# ### MED

# %% [markdown]
# ### SolarMED

# %%
# Load result
from solarmed_modeling.solar_med.benchmark import model_id

# ["Tsf_in", "Tsf_out", "Thx_s_out", *Th_labels, *Tc_labels, "qmed_d", "qmed_c"]
metrics_of_interest = ['mae', 'mape']
if "r2" in metric_info.keys():
    metric_info.pop("r2")

out_vars_dict = {
    "Tsf_in": "T$_{sf,in}$ ($^\\circ$C)",
    "Tsf_out": "T$_{sf,out}$ ($^\\circ$C)",
    "Tts_h_t": "T$_{ts,h}$ ($^\\circ$C)",
    "Tts_c_b": "T$_{ts,c}$ ($^\\circ$C)",
    "qmed_d": "q$_{med,d}$ (m$^3$/h)",
    # "Tmed_s_out": "T$_{med,s,out}$ ($^\\circ$C)",
    # "qmed_c": "q$_{med,c}$ (m$^3$/h)",
    # "Pth_sf": "$\dot{Q}_{sf}$ (kW$_{th}$)",
    # "Pth_ts_src": "$\dot{Q}_{ts,src}$ (kW$_{th}$)",
    # "Pth_ts_dis": "$\dot{Q}_{med,s}$ (kW$_{th}$)",
    # "Ets_h": "Q$_{ts,h}$ (kWh$_{th}$)",
    # "Ets_c": "Q$_{ts,c}$ (kWh$_{th}$)",
}
out_var_ids = list(out_vars_dict.keys())

# eval_date_str = "20250720"
selected_alternatives: list[str] = ["constant-water-props"]
selected_sample_times: list[int] = [400]

filter_out_tests = [
    "20230505",
    "20231031",
    "20230703",
    "20230508",
    "20230630",
    "20230629"
]

regular_col_ids = [
    "variable",
    # "modelling_alternative",
    # "sample_time",
    "test_id",
]
regular_col_labels = [
    r"Predicted\\ variable",
    # r"Modelling\\ principle",
    # r"Sample\\ time\\ (s)",
    r"Test\\ date",
]


stats = import_benchmark_results(results_path=results_path, model_id=model_id, eval_date_str=eval_date_str)
# stats

# %%
# Parse results dict into compatible format for latex table

table_data = parse_benchmark_results_to_latex_data(
    selected_alternatives=selected_alternatives,
    selected_sample_times=selected_sample_times,
    out_var_ids=out_var_ids,
    stats=stats,
    out_vars_dict=out_vars_dict,
)
# Out:
# 2025-09-10 16:51:57.164 | INFO     | __main__:parse_benchmark_results_to_latex_data:102 - Processing alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.166 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_in, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.166 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_in, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.168 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.168 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.169 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.170 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.171 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.172 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.173 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: qmed_d, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.166 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_in, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.166 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_in, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.168 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_out, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.168 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tsf_out, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.169 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.170 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_h_t, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.171 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.172 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: Tts_c_b, test id: 20231106, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.173 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: qmed_d, test id: 20231030, alternative: constant-water-props, sample time: 400 s
# 2025-09-10 16:51:57.174 | INFO     | __main__:parse_benchmark_results_to_latex_data:133 - Added data for variable: qmed_d, test id: 20231106, alternative: constant-water-props, sample time: 400 s

# %%
table_str = generate_latex_table(
    regular_col_ids,
    regular_col_labels,
    metric_info,
    table_data,
    submetric_ids,
    group_row_ids,
    submetric_labels,
    group_submetric_ids
)

print(table_str)
# Out:
# \begin{tabular}{ccccccccccccccc}
# \hline
# \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Predicted\\ variable\end{tabular}}} &  & \multirow{3}{*}{\textbf{\begin{tabular}[c]{@{}c@{}}Test\\ date\end{tabular}}} &  & \multicolumn{11}{c}{\textbf{Performance metric}}
# \\\cline{5-15}
#  &  &  &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAE\\ (s.u.)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}MAPE\\ (\%)\end{tabular}}} &  & \multicolumn{3}{c}{\textbf{\begin{tabular}[c]{@{}c@{}}Time\\ (s)\end{tabular}}}
#  \\\cline{5-7}\cline{9-11}\cline{13-15}
#  &  &  &  & Test &  & Avg. &  & Test &  & Avg. &  & Test &  & Avg.
#  \\\cline{1-1}\cline{3-3}\cline{5-5}\cline{7-7}\cline{9-9}\cline{11-11}\cline{13-13}\cline{15-15}
# \multirow{2}{*}{T$_{sf,in}$ ($^\circ$C)} &  & 20231030 &  & 6.43 &  & \multirow{2}{*}{5.57} &  & 13.48 &  & \multirow{2}{*}{12.81} &  & 2.00 &  & \multirow{10}{*}{2.47} \\
#  &  & 20231106 &  & 4.71 &  &  &  & 12.13 &  &  &  & 2.95 &  &  \\
# \multirow{2}{*}{T$_{sf,out}$ ($^\circ$C)} &  & 20231030 &  & 7.55 &  & \multirow{2}{*}{6.57} &  & 15.66 &  & \multirow{2}{*}{14.85} &  & 2.00 &  &  \\
#  &  & 20231106 &  & 5.60 &  &  &  & 14.03 &  &  &  & 2.95 &  &  \\
# \multirow{2}{*}{T$_{ts,h}$ ($^\circ$C)} &  & 20231030 &  & 0.79 &  & \multirow{2}{*}{3.92} &  & 0.84 &  & \multirow{2}{*}{4.40} &  & 2.00 &  &  \\
#  &  & 20231106 &  & 7.05 &  &  &  & 7.97 &  &  &  & 2.95 &  &  \\
# \multirow{2}{*}{T$_{ts,c}$ ($^\circ$C)} &  & 20231030 &  & 2.97 &  & \multirow{2}{*}{2.53} &  & 3.68 &  & \multirow{2}{*}{3.42} &  & 2.00 &  &  \\
#  &  & 20231106 &  & 2.09 &  &  &  & 3.16 &  &  &  & 2.95 &  &  \\
# \multirow{2}{*}{q$_{med,d}$ (m$^3$/h)} &  & 20231030 &  & 0.35 &  & \multirow{2}{*}{0.69} &  & 33.28 &  & \multirow{2}{*}{25.29} &  & 2.00 &  &  \\
#  &  & 20231106 &  & 1.02 &  &  &  & 17.29 &  &  &  & 2.95 &  &  \\
# \hline
# \end{tabular}
