# %%
import evox
from evox import algorithms, problems, workflows, monitors, use_state

import jax.numpy as jnp
from jax import random
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import evox
#       2 from evox import algorithms, problems, workflows, monitors, use_state
#       4 import jax.numpy as jnp
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/evox/__init__.py:1
# ----> 1 from .core.workflow import Workflow
#       2 from .core.algorithm import Algorithm, has_init_ask, has_init_tell
#       3 from .core.module import use_state, jit_class, jit_method, Stateful
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/evox/core/workflow.py:1
# ----> 1 from .module import *
#       4 class Workflow(Stateful):
#       5     pass
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/evox/core/module.py:7
#       4 from collections import namedtuple
#       5 from typing import Annotated, Any, Callable, Optional, Tuple, TypeVar, get_type_hints
# ----> 7 import jax
#       8 import jax.numpy as jnp
#       9 import numpy as np
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jax/__init__.py:25
#      22 from jax.version import __version_info__ as __version_info__
#      24 # Set Cloud TPU env vars if necessary before transitively loading C++ backend
# ---> 25 from jax._src.cloud_tpu_init import cloud_tpu_init as _cloud_tpu_init
#      26 try:
#      27   _cloud_tpu_init()
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jax/_src/cloud_tpu_init.py:17
#      15 import os
#      16 from jax import version
# ---> 17 from jax._src import config
#      18 from jax._src import hardware_utils
#      20 running_in_cloud_tpu_vm: bool = False
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jax/_src/config.py:26
#      23 import sys
#      24 from typing import Any, Generic, NoReturn, Optional, Protocol, TypeVar, cast
# ---> 26 from jax._src.lib import guard_lib
#      27 from jax._src.lib import jax_jit
#      28 from jax._src.lib import xla_client
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jax/_src/lib/__init__.py:87
#      84 cpu_feature_guard.check_cpu_features()
#      86 import jaxlib.utils as utils  # noqa: F401
# ---> 87 import jaxlib.xla_client as xla_client
#      88 import jaxlib.lapack as lapack  # noqa: F401
#      90 xla_extension = xla_client._xla
#
# File /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jaxlib/xla_client.py:33
#      30 import ml_dtypes
#      31 import numpy as np
# ---> 33 from . import xla_extension as _xla
#      35 # Note this module does *not* depend on any Python protocol buffers. The XLA
#      36 # Python bindings are currently packaged both as part of jaxlib and as part
#      37 # of TensorFlow. If we use protocol buffers here, then importing both jaxlib
#    (...)
#      44 # Pylint has false positives for type annotations.
#      45 # pylint: disable=invalid-sequence-index
#      47 ifrt_programs = _xla.ifrt_programs
#
# ImportError: /lib/x86_64-linux-gnu/libc.so.6: version `GLIBC_2.38' not found (required by /workspaces/SolarMED-optimization/.venv/lib/python3.11/site-packages/jaxlib/xla_extension.so)
