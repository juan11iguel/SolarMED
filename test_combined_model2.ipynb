# %%
from pathlib import Path
import os
import hjson
import json
import numpy as np
import pandas as pd
from collections import OrderedDict
from IPython.display import display
from loguru import logger
from phd_visualizations.utils.units import unit_conversion

# Setup environment for running MATLAB code if not done externally
import os

# os.environ["MR"] = f"{os.environ['HOME']}/PSA/MATLAB_runtime/R2023b"
os.environ["MR"] = f"{os.environ['HOME']}/MATLAB/R2023b"
MR = os.environ["MR"]
os.environ["LD_LIBRARY_PATH"] = f"{MR}/runtime/glnxa64:{MR}/bin/glnxa64:{MR}/sys/os/glnxa64:{MR}/sys/opengl/lib/glnxa64"

from phd_visualizations import save_figure
from phd_visualizations.constants import generate_plotly_config

# auto reload modules
# %load_ext autoreload

# Paths definition
src_path = Path(f'{os.getenv("HOME")}/Nextcloud/Juanmi_MED_PSA/EURECAT/')
results_path: Path = src_path / 'results'
data_path: Path = src_path / 'data'

# filename_opt_result = '20240108_optimization_results.json'
# Debería ser un .csv al que se le hayan añadido las variables faltantes desde librescada:
# - J de variadores y medidor de potencia
# - FT-DES-002_VFD

filename_process_data = '20231030_solarMED.csv'
filename_process_data2 = '20231030_MED.csv'

# Resample figures using plotly_resampler
resample_figures = False

sample_rate = '60s'
sample_rate_numeric = int(sample_rate[:-1])

# Parameters
cost_w: float = 3 # €/m³, cost of water
cost_e: float = 0.05 # €/kWh, cost of electricity

# initial_datetime = '2024-01-08 10:55'
# final_datetime = '2024-01-08 14:00'

# Load variables information
with open( Path("data") / 'variables_config.hjson') as f:
    vars_config = hjson.load(f)

# Load plot configuration
with open( Path("data") / "plot_config.hjson") as f:
    plt_config = hjson.load(f)
    
# Read data from csv, the index column is the one named "time", which is not the first one
df = pd.read_csv(data_path / filename_process_data, parse_dates=True, index_col='TimeStamp')
# Rename index column to "time"
df.index.names = ['time']
# Set UTC timezone
df = df.tz_localize('UTC')

# TEMP: Read additional MED data from librescada logging, in the future everything should be read directly from librescada
df_aux = pd.read_csv(data_path / filename_process_data2, parse_dates=True, index_col='time')
# Set UTC timezone
df_aux = df_aux.tz_localize('UTC')
# Add columns from df_aux to df
df = pd.concat([df, df_aux], axis=1)

display(df.head())

# Preprocessing
from phd_visualizations.utils import rename_signal_ids_to_var_ids

# %autoreload 2

# Sample every `sample_rate` seconds to reduce the size of the dataframe
df = df.resample(sample_rate).mean()

# Rename columns from signal_id to var_id
df = rename_signal_ids_to_var_ids(df, vars_config)

display(df.head())

df["Jmed_e"] = df['Jmed_b'] + df['Jmed_c'] + df['Jmed_d'] + df['Jmed_s_f']*1e-3 # kW

# Convert units to model units
df = unit_conversion(df, vars_config, input_unit_key='units_scada', output_unit_key='units_model')

# Filter out nans until first value in Tts
start_idx = df.index.get_loc( df['Tts_c_b'].first_valid_index() )
df = df.iloc[start_idx:]
logger.info(f'Removed up to row {start_idx} to filter NaN values in thermal storage state')

display(df.head())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                            FT-AQU-100  FT-AQU-101  TT-AQU-106  TT-AQU-107a  \
# time
# 2023-10-30 07:30:00+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:01+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:02+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:03+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:04+00:00    0.008681         NaN         NaN          NaN
#
#                            TT-AQU-109  CT-DES-001  FT-DES-003  FT-DES-005  \
# time
# 2023-10-30 07:30:00+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:01+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:02+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:03+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:04+00:00         NaN         NaN         NaN         NaN
#
#                            SW2TC1  TE-DES-015  ...  TT-SF-007  TT-SF-008  \
# time                                           ...
# 2023-10-30 07:30:00+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:01+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:02+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:03+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:04+00:00     NaN        16.0  ...        NaN        NaN
#
#                            TT-SF-009  TT-SF-010  vfd_prod_power  \
# time
# 2023-10-30 07:30:00+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:01+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:02+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:03+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:04+00:00        NaN        NaN             NaN
#
#                            PK-MED-E01-pa  vfd_brine_power  HW1TT21  \
# time
# 2023-10-30 07:30:00+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:01+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:02+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:03+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:04+00:00            NaN              NaN      NaN
#
#                            vfd_sw_power  FT-DES-002_VFD
# time
# 2023-10-30 07:30:00+00:00           NaN             NaN
# 2023-10-30 07:30:01+00:00           NaN             NaN
# 2023-10-30 07:30:02+00:00           NaN             NaN
# 2023-10-30 07:30:03+00:00           NaN             NaN
# 2023-10-30 07:30:04+00:00           NaN             NaN
#
# [5 rows x 30 columns]
# 2024-02-27 09:01:20.149 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id FT-SF-003 not found in dataframe columns.
# 2024-02-27 09:01:20.150 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id FT-SF-005 not found in dataframe columns.
# 2024-02-27 09:01:20.150 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id FT-SF-006 not found in dataframe columns.
# 2024-02-27 09:01:20.151 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id FT-SF-007 not found in dataframe columns.
# 2024-02-27 09:01:20.151 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id FT-SF-008 not found in dataframe columns.
# 2024-02-27 09:01:20.151 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-018 not found in dataframe columns.
# 2024-02-27 09:01:20.152 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-019 not found in dataframe columns.
# 2024-02-27 09:01:20.152 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-024 not found in dataframe columns.
# 2024-02-27 09:01:20.153 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-025 not found in dataframe columns.
# 2024-02-27 09:01:20.153 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-030 not found in dataframe columns.
# 2024-02-27 09:01:20.153 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-031 not found in dataframe columns.
# 2024-02-27 09:01:20.154 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-036 not found in dataframe columns.
# 2024-02-27 09:01:20.154 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:38 - Signal id TT-SF-037 not found in dataframe columns.
#                              qmed_s  qts_dis  Tts_h_out  Tmed_s_in  \
# time
# 2023-10-30 07:30:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:31:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:32:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:33:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:34:00+00:00  0.008681      NaN        NaN        NaN
#
#                            Tts_c_b_in  wmed_f  qmed_f  qmed_d  Tmed_c_out  \
# time
# 2023-10-30 07:30:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:31:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:32:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:33:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:34:00+00:00         NaN     NaN     NaN     NaN         NaN
#
#                            Tmed_c_in  ...  Thx_p_out  Thx_s_in  Thx_s_out  \
# time                                  ...
# 2023-10-30 07:30:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:31:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:32:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:33:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:34:00+00:00       16.0  ...        NaN       NaN        NaN
#
#                            qhx_p  qhx_s  T3wv_src  T3wv_dis_in  T3wv_dis_out  \
# time
# 2023-10-30 07:30:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:31:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:32:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:33:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:34:00+00:00    0.0    0.0       NaN          NaN           NaN
#
#                            q3wv_src  q3wv_dis
# time
# 2023-10-30 07:30:00+00:00       NaN  0.008681
# 2023-10-30 07:31:00+00:00       NaN  0.008681
# 2023-10-30 07:32:00+00:00       NaN  0.008681
# 2023-10-30 07:33:00+00:00       NaN  0.008681
# 2023-10-30 07:34:00+00:00       NaN  0.008681
#
# [5 rows x 44 columns]
# 2024-02-27 09:01:20.183 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tamb to C from C
# 2024-02-27 09:01:20.184 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_c_in to C from C
# 2024-02-27 09:01:20.185 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_s_in to C from C
# 2024-02-27 09:01:20.187 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_s_out to C from C
# 2024-02-27 09:01:20.188 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_c_out to C from C
# 2024-02-27 09:01:20.189 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_in to C from C
# 2024-02-27 09:01:20.191 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_out to C from C
# 2024-02-27 09:01:20.192 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_t_in to C from C
# 2024-02-27 09:01:20.193 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_src_in to C from C
# 2024-02-27 09:01:20.194 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_out to C from C
# 2024-02-27 09:01:20.195 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis to C from C
# 2024-02-27 09:01:20.196 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_in to C from C
# 2024-02-27 09:01:20.198 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_out to C from C
# 2024-02-27 09:01:20.199 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis_in to C from C
# 2024-02-27 09:01:20.201 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_t to C from C
# 2024-02-27 09:01:20.203 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_m to C from C
# 2024-02-27 09:01:20.204 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_b to C from C
# 2024-02-27 09:01:20.205 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_t to C from C
# 2024-02-27 09:01:20.206 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_m to C from C
# 2024-02-27 09:01:20.208 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b to C from C
# 2024-02-27 09:01:20.210 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_in to C from C
# 2024-02-27 09:01:20.211 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_out to C from C
# 2024-02-27 09:01:20.212 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_in to C from C
# 2024-02-27 09:01:20.213 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_out to C from C
# 2024-02-27 09:01:20.215 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_src to C from C
# 2024-02-27 09:01:20.217 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_dis_in to C from C
# 2024-02-27 09:01:20.218 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_dis_out to C from C
# 2024-02-27 09:01:20.218 | INFO     | phd_visualizations.utils.units:unit_conversion:536 - No unit conversion needed for I, just performing renaming if set in `update_mode`: I_Wm2
# 2024-02-27 09:01:20.220 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated I to Wm2 from Wm2
# 2024-02-27 09:01:20.220 | WARNING  | phd_visualizations.utils.units:unsupported_unit_conversion_msg:89 - Asked for unsupported unit conversion: mScm -> gkg. Skipping unit conversion.
# 2024-02-27 09:01:20.221 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.223 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_s to m3h from Ls
# 2024-02-27 09:01:20.224 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_f_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.225 | WARNING  | phd_visualizations.utils.units:unit_conversion:491 - Could not find any variable matching Tmed_f*_K in available variables. Using default value of 298.15 K
# 2024-02-27 09:01:20.226 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_f to m3h from m3h
# 2024-02-27 09:01:20.226 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_c_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.229 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_c to m3h from m3h
# 2024-02-27 09:01:20.230 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_d_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.231 | WARNING  | phd_visualizations.utils.units:unit_conversion:491 - Could not find any variable matching Tmed_d*_K in available variables. Using default value of 298.15 K
# 2024-02-27 09:01:20.231 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_d to m3h from m3h
# 2024-02-27 09:01:20.232 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_d to kW from kW
# 2024-02-27 09:01:20.233 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_b to kW from kW
# 2024-02-27 09:01:20.234 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_c to kW from W
# 2024-02-27 09:01:20.234 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_s_f to kW from W
# 2024-02-27 09:01:20.235 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Psf_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.238 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qsf to m3h from Lmin
# 2024-02-27 09:01:20.238 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.241 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_dis to m3h from Ls
# 2024-02-27 09:01:20.241 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.243 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_src to m3h from Lmin
# 2024-02-27 09:01:20.244 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_p_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.246 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_p to m3h from Lmin
# 2024-02-27 09:01:20.247 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.249 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_s to m3h from Lmin
# 2024-02-27 09:01:20.250 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.252 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_src to m3h from Ls
# 2024-02-27 09:01:20.252 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-27 09:01:20.254 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_dis to m3h from Ls
# 2024-02-27 09:01:20.256 | INFO     | __main__:<module>:97 - Removed up to row 14 to filter NaN values in thermal storage state
#                             qmed_s   qts_dis  Tts_h_out  Tmed_s_in  \
# time
# 2023-10-30 07:44:00+00:00  0.03125  0.034011  17.423900  17.662380
# 2023-10-30 07:45:00+00:00  0.03125  0.033959  17.432972  17.660400
# 2023-10-30 07:46:00+00:00  0.03125  0.034200  17.430652  17.649843
# 2023-10-30 07:47:00+00:00  0.03125  0.034135  17.429460  17.639787
# 2023-10-30 07:48:00+00:00  0.03125  0.034047  17.432343  17.645888
#
#                            Tts_c_b_in     wmed_f    qmed_f    qmed_d  \
# time
# 2023-10-30 07:44:00+00:00   26.683404  35.328423  0.010750  0.000816
# 2023-10-30 07:45:00+00:00   26.681435  35.351805  0.010662  0.000818
# 2023-10-30 07:46:00+00:00   26.670880  35.418997  0.010647  0.000802
# 2023-10-30 07:47:00+00:00   26.663742  35.427615  0.010652  0.000808
# 2023-10-30 07:48:00+00:00   26.655250  35.422630  0.010637  0.000806
#
#                            Tmed_c_out  Tmed_c_in  ...   Thx_s_in  Thx_s_out  \
# time                                              ...
# 2023-10-30 07:44:00+00:00   16.069060       16.0  ...  15.296492  16.923871
# 2023-10-30 07:45:00+00:00   16.067952       16.0  ...  15.296910  16.952170
# 2023-10-30 07:46:00+00:00   16.031067       16.0  ...  15.296857  17.009618
# 2023-10-30 07:47:00+00:00   16.057810       16.0  ...  15.296970  17.080558
# 2023-10-30 07:48:00+00:00   16.035168       16.0  ...  15.297030  17.168850
#
#                               qhx_p  qhx_s   T3wv_src  T3wv_dis_in  \
# time
# 2023-10-30 07:44:00+00:00  0.000000    0.0  96.424700    17.662380
# 2023-10-30 07:45:00+00:00  0.000000    0.0  96.422570    17.660400
# 2023-10-30 07:46:00+00:00  4.996789    0.0  96.415720    17.649843
# 2023-10-30 07:47:00+00:00  5.679213    0.0  96.413525    17.639787
# 2023-10-30 07:48:00+00:00  5.675256    0.0  96.412153    17.645888
#
#                            T3wv_dis_out  q3wv_src  q3wv_dis  Jmed_e
# time
# 2023-10-30 07:44:00+00:00     26.683404  0.034011   0.03125     NaN
# 2023-10-30 07:45:00+00:00     26.681435  0.033959   0.03125     NaN
# 2023-10-30 07:46:00+00:00     26.670880  0.034200   0.03125     NaN
# 2023-10-30 07:47:00+00:00     26.663742  0.034135   0.03125     NaN
# 2023-10-30 07:48:00+00:00     26.655250  0.034047   0.03125     NaN
#
# [5 rows x 45 columns]

# %%
from models_psa import calculate_aux_variables, calculate_powers_solar_field, calculate_powers_thermal_storage

df = calculate_aux_variables(df, cost_w, cost_e, sample_rate_numeric)
df = df.apply(calculate_powers_solar_field, args=(250, 0, False), axis=1)
df = df.apply(calculate_powers_thermal_storage, axis=1)

# %%
df.to_csv('data/dev.csv')

# %%
# Test model
from models_psa import SolarMED

# %autoreload 2

# Initialize model
model = SolarMED(
    sample_time=sample_rate_numeric,
    curve_fits_path='data/curve_fits.json',
    
    # Initial states. Thermal storage
    Tts_h=[df['Tts_h_t'].iloc[0], df['Tts_h_m'].iloc[0], df['Tts_h_b'].iloc[0]], 
    Tts_c=[df['Tts_c_t'].iloc[0], df['Tts_c_m'].iloc[0], df['Tts_c_b'].iloc[0]],
    Tsf_in=df['Tsf_in'].iloc[0],
    
    cost_w = cost_w, # €/m³ 
    cost_e = cost_e # €/kWhe
)
# Out:
# 2024-02-25 18:59:47.093 | INFO     | models_psa:init_matlab_engine:784 - MATLAB engine initialized

# %%
# Run model
idx = 1
ds = df.iloc[idx]
# df.to_csv('data/dev.csv')

model.step(
    # Decision variables
    ## MED
    mmed_s=ds['qmed_s'],
    mmed_f=ds['qmed_f'],
    Tmed_s_in=ds['Tmed_s_in'],
    Tmed_c_out=ds['Tmed_c_out'],
    ## Thermal storage
    mts_src=ds['qts_src'],
    ## Solar field
    Tsf_out=ds['Tsf_out'],
    
    # Environment variables
    Tmed_c_in=ds['Tmed_c_in'],
    Tamb=ds['Tamb'],
    I=ds['I'],
)

iteration_result = model.model_dump()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 idx = 1
#       3 ds = df.iloc[idx]
# ----> 5 model.step(
#       6     # Decision variables
#       7     ## MED
#       8     mmed_s=ds['qmed_s'],
#       9     mmed_f=ds['qmed_f'],
#      10     Tmed_s_in=ds['Tmed_s_in'],
#      11     Tmed_c_out=ds['Tmed_c_out'],
#      12     ## Thermal storage
#      13     mts_src=ds['qts_src'],
#      14     ## Solar field
#      15     Tsf_out=ds['Tsf_out'],
#      16
#      17     # Environment variables
#      18     Tmed_c_in=ds['Tmed_c_in'],
#      19     Tamb=ds['Tamb'],
#      20     I=ds['I'],
#      21 )
#      23 iteration_result = model.model_dump()
#
# File ~/development_psa/models_psa/models_psa/__init__.py:630, in SolarMED.step(self, mmed_s, mmed_f, Tmed_s_in, Tmed_c_out, mts_src, Tsf_out, Tmed_c_in, Tamb, I, wmed_f)
#     628 self.mmed_s_sp = mmed_s
#     629 self.mmed_f_sp = mmed_f
# --> 630 self.Tmed_s_in_sp = Tmed_s_in
#     631 self.Tmed_c_out_sp = Tmed_c_out
#     632 # Thermal storage
#
# File ~/development_psa/models_psa/venv/lib/python3.11/site-packages/pydantic/main.py:792, in BaseModel.__setattr__(self, name, value)
#     790     attr.__set__(self, value)
#     791 elif self.model_config.get('validate_assignment', None):
# --> 792     self.__pydantic_validator__.validate_assignment(self, name, value)
#     793 elif self.model_config.get('extra') != 'allow' and name not in self.model_fields:
#     794     # TODO - matching error
#     795     raise ValueError(f'"{self.__class__.__name__}" object has no field "{name}"')
#
# File ~/development_psa/models_psa/models_psa/__init__.py:312, in SolarMED.validate_Tmed_s_in(cls, Tmed_s_in, info)
#     305 @field_validator("Tmed_s_in_sp")
#     306 @classmethod
#     307 def validate_Tmed_s_in(cls, Tmed_s_in: float, info: ValidationInfo) -> float:
#     308     # Lower limit set by pre-defined operational limit, if lower -> 0
#     309     # Upper bound, take the lower between the hot tank top temperature and the pre-defined operational limit
#     310     return within_range_or_zero_or_max(
#     311         Tmed_s_in, range=( info.data["lims_Tmed_s_in"][0],
# --> 312                            np.min(info.data["lims_Tmed_s_in"][1], info.data["Tts_h"][0]) )
#     313     )
#
# File ~/development_psa/models_psa/venv/lib64/python3.11/site-packages/numpy/core/fromnumeric.py:2953, in min(a, axis, out, keepdims, initial, where)
#    2836 @array_function_dispatch(_min_dispatcher)
#    2837 def min(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2838         where=np._NoValue):
#    2839     """
#    2840     Return the minimum of an array or minimum along an axis.
#    2841
#    (...)
#    2951     6
#    2952     """
# -> 2953     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2954                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/development_psa/models_psa/venv/lib64/python3.11/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: 'float' object cannot be interpreted as an integer
