# %%
from pathlib import Path
import os
import hjson
import json
import numpy as np
import pandas as pd
from collections import OrderedDict
from IPython.display import display
from loguru import logger
from phd_visualizations.utils.units import unit_conversion

# Setup environment for running MATLAB code if not done externally
import os

os.environ["MR"] = f"{os.environ['HOME']}/PSA/MATLAB_runtime/R2023b"
MR = os.environ["MR"]
os.environ["LD_LIBRARY_PATH"] = f"{MR}/runtime/glnxa64:{MR}/bin/glnxa64:{MR}/sys/os/glnxa64:{MR}/sys/opengl/lib/glnxa64"

from phd_visualizations import save_figure
from phd_visualizations.constants import generate_plotly_config

# auto reload modules
# %load_ext autoreload

# Paths definition
src_path = Path(f'{os.getenv("HOME")}/Nextcloud/Juanmi_MED_PSA/EURECAT/')
results_path: Path = src_path / 'results'
data_path: Path = src_path / 'data'

# filename_opt_result = '20240108_optimization_results.json'
# Debería ser un .csv al que se le hayan añadido las variables faltantes desde librescada:
# - J de variadores y medidor de potencia
# - FT-DES-002_VFD

filename_process_data = '20231030_solarMED.csv'
filename_process_data2 = '20231030_MED.csv'

# Resample figures using plotly_resampler
resample_figures = False

sample_rate = '60s'
sample_rate_numeric = int(sample_rate[:-1])

# Parameters
cost_w: float = 3 # €/m³, cost of water
cost_e: float = 0.05 # €/kWh, cost of electricity

# initial_datetime = '2024-01-08 10:55'
# final_datetime = '2024-01-08 14:00'

# Load variables information
with open( Path("data") / 'variables_config.hjson') as f:
    vars_config = hjson.load(f)

# Load plot configuration
with open( Path("data") / "plot_config.hjson") as f:
    plt_config = hjson.load(f)
    
# Read data from csv, the index column is the one named "time", which is not the first one
df = pd.read_csv(data_path / filename_process_data, parse_dates=True, index_col='TimeStamp')
# Rename index column to "time"
df.index.names = ['time']
# Set UTC timezone
df = df.tz_localize('UTC')

# TEMP: Read additional MED data from librescada logging, in the future everything should be read directly from librescada
df_aux = pd.read_csv(data_path / filename_process_data2, parse_dates=True, index_col='time')
# Set UTC timezone
df_aux = df_aux.tz_localize('UTC')
# Add columns from df_aux to df
df = pd.concat([df, df_aux], axis=1)

display(df.head())

# Preprocessing
from phd_visualizations.utils import rename_signal_ids_to_var_ids

# %autoreload 2

# Sample every `sample_rate` seconds to reduce the size of the dataframe
df = df.resample(sample_rate).mean()

# Rename columns from signal_id to var_id
df = rename_signal_ids_to_var_ids(df, vars_config)

display(df.head())

df["Jmed_e"] = df['Jmed_b'] + df['Jmed_c'] + df['Jmed_d'] + df['Jmed_s_f']*1e-3 # kW

# Convert units to model units
df = unit_conversion(df, vars_config, input_unit_key='units_scada', output_unit_key='units_model')

# Filter out nans until first value in Tts
start_idx = df.index.get_loc( df['Tts_c_b'].first_valid_index() )
df = df.iloc[start_idx:]
logger.info(f'Removed up to row {start_idx} to filter NaN values in thermal storage state')

display(df.head())
# Out:
#                            FT-AQU-100  FT-AQU-101  TT-AQU-106  TT-AQU-107a  \
# time
# 2023-10-30 07:30:00+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:01+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:02+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:03+00:00    0.008681         NaN         NaN          NaN
# 2023-10-30 07:30:04+00:00    0.008681         NaN         NaN          NaN
#
#                            TT-AQU-109  CT-DES-001  FT-DES-003  FT-DES-005  \
# time
# 2023-10-30 07:30:00+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:01+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:02+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:03+00:00         NaN         NaN         NaN         NaN
# 2023-10-30 07:30:04+00:00         NaN         NaN         NaN         NaN
#
#                            SW2TC1  TE-DES-015  ...  TT-SF-007  TT-SF-008  \
# time                                           ...
# 2023-10-30 07:30:00+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:01+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:02+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:03+00:00     NaN        16.0  ...        NaN        NaN
# 2023-10-30 07:30:04+00:00     NaN        16.0  ...        NaN        NaN
#
#                            TT-SF-009  TT-SF-010  vfd_prod_power  \
# time
# 2023-10-30 07:30:00+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:01+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:02+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:03+00:00        NaN        NaN             NaN
# 2023-10-30 07:30:04+00:00        NaN        NaN             NaN
#
#                            PK-MED-E01-pa  vfd_brine_power  HW1TT21  \
# time
# 2023-10-30 07:30:00+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:01+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:02+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:03+00:00            NaN              NaN      NaN
# 2023-10-30 07:30:04+00:00            NaN              NaN      NaN
#
#                            vfd_sw_power  FT-DES-002_VFD
# time
# 2023-10-30 07:30:00+00:00           NaN             NaN
# 2023-10-30 07:30:01+00:00           NaN             NaN
# 2023-10-30 07:30:02+00:00           NaN             NaN
# 2023-10-30 07:30:03+00:00           NaN             NaN
# 2023-10-30 07:30:04+00:00           NaN             NaN
#
# [5 rows x 30 columns]
#                              qmed_s  qts_dis  Tts_h_out  Tmed_s_in  \
# time
# 2023-10-30 07:30:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:31:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:32:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:33:00+00:00  0.008681      NaN        NaN        NaN
# 2023-10-30 07:34:00+00:00  0.008681      NaN        NaN        NaN
#
#                            Tts_c_b_in  wmed_f  qmed_f  qmed_d  Tmed_c_out  \
# time
# 2023-10-30 07:30:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:31:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:32:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:33:00+00:00         NaN     NaN     NaN     NaN         NaN
# 2023-10-30 07:34:00+00:00         NaN     NaN     NaN     NaN         NaN
#
#                            Tmed_c_in  ...  Thx_p_out  Thx_s_in  Thx_s_out  \
# time                                  ...
# 2023-10-30 07:30:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:31:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:32:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:33:00+00:00       16.0  ...        NaN       NaN        NaN
# 2023-10-30 07:34:00+00:00       16.0  ...        NaN       NaN        NaN
#
#                            qhx_p  qhx_s  T3wv_src  T3wv_dis_in  T3wv_dis_out  \
# time
# 2023-10-30 07:30:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:31:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:32:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:33:00+00:00    0.0    0.0       NaN          NaN           NaN
# 2023-10-30 07:34:00+00:00    0.0    0.0       NaN          NaN           NaN
#
#                            q3wv_src  q3wv_dis
# time
# 2023-10-30 07:30:00+00:00       NaN  0.008681
# 2023-10-30 07:31:00+00:00       NaN  0.008681
# 2023-10-30 07:32:00+00:00       NaN  0.008681
# 2023-10-30 07:33:00+00:00       NaN  0.008681
# 2023-10-30 07:34:00+00:00       NaN  0.008681
#
# [5 rows x 44 columns]
# 2024-02-20 09:14:48.200 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tamb to C from C
# 2024-02-20 09:14:48.202 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_c_in to C from C
# 2024-02-20 09:14:48.202 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_s_in to C from C
# 2024-02-20 09:14:48.203 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_s_out to C from C
# 2024-02-20 09:14:48.204 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_c_out to C from C
# 2024-02-20 09:14:48.205 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_in to C from C
# 2024-02-20 09:14:48.206 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_out to C from C
# 2024-02-20 09:14:48.207 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_t_in to C from C
# 2024-02-20 09:14:48.208 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_src_in to C from C
# 2024-02-20 09:14:48.209 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_out to C from C
# 2024-02-20 09:14:48.209 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis to C from C
# 2024-02-20 09:14:48.210 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_in to C from C
# 2024-02-20 09:14:48.211 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_out to C from C
# 2024-02-20 09:14:48.212 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis_in to C from C
# 2024-02-20 09:14:48.212 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_t to C from C
# 2024-02-20 09:14:48.213 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_m to C from C
# 2024-02-20 09:14:48.214 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_b to C from C
# 2024-02-20 09:14:48.215 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_t to C from C
# 2024-02-20 09:14:48.216 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_m to C from C
# 2024-02-20 09:14:48.216 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b to C from C
# 2024-02-20 09:14:48.217 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_in to C from C
# 2024-02-20 09:14:48.218 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_out to C from C
# 2024-02-20 09:14:48.218 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_in to C from C
# 2024-02-20 09:14:48.219 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_out to C from C
# 2024-02-20 09:14:48.220 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_src to C from C
# 2024-02-20 09:14:48.221 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_dis_in to C from C
# 2024-02-20 09:14:48.221 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_dis_out to C from C
# 2024-02-20 09:14:48.222 | INFO     | phd_visualizations.utils.units:unit_conversion:536 - No unit conversion needed for I, just performing renaming if set in `update_mode`: I_Wm2
# 2024-02-20 09:14:48.222 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated I to Wm2 from Wm2
# 2024-02-20 09:14:48.223 | WARNING  | phd_visualizations.utils.units:unsupported_unit_conversion_msg:89 - Asked for unsupported unit conversion: mScm -> gkg. Skipping unit conversion.
# 2024-02-20 09:14:48.223 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.226 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_s to m3h from Ls
# 2024-02-20 09:14:48.226 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_f_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.226 | WARNING  | phd_visualizations.utils.units:unit_conversion:491 - Could not find any variable matching Tmed_f*_K in available variables. Using default value of 298.15 K
# 2024-02-20 09:14:48.227 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_f to m3h from m3h
# 2024-02-20 09:14:48.227 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_c_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.229 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_c to m3h from m3h
# 2024-02-20 09:14:48.229 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_d_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.230 | WARNING  | phd_visualizations.utils.units:unit_conversion:491 - Could not find any variable matching Tmed_d*_K in available variables. Using default value of 298.15 K
# 2024-02-20 09:14:48.230 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_d to m3h from m3h
# 2024-02-20 09:14:48.230 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_d to kW from kW
# 2024-02-20 09:14:48.231 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_b to kW from kW
# 2024-02-20 09:14:48.231 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_c to kW from W
# 2024-02-20 09:14:48.232 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_s_f to kW from W
# 2024-02-20 09:14:48.232 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Psf_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.234 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qsf to m3h from Lmin
# 2024-02-20 09:14:48.234 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.236 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_dis to m3h from Ls
# 2024-02-20 09:14:48.236 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.237 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_src to m3h from Lmin
# 2024-02-20 09:14:48.238 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_p_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.239 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_p to m3h from Lmin
# 2024-02-20 09:14:48.239 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.241 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_s to m3h from Lmin
# 2024-02-20 09:14:48.241 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.242 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_src to m3h from Ls
# 2024-02-20 09:14:48.243 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-02-20 09:14:48.244 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_dis to m3h from Ls
# 2024-02-20 09:14:48.245 | INFO     | __main__:<module>:96 - Removed up to row 14 to filter NaN values in thermal storage state
#                             qmed_s   qts_dis  Tts_h_out  Tmed_s_in  \
# time
# 2023-10-30 07:44:00+00:00  0.03125  0.034011  17.423900  17.662380
# 2023-10-30 07:45:00+00:00  0.03125  0.033959  17.432972  17.660400
# 2023-10-30 07:46:00+00:00  0.03125  0.034200  17.430652  17.649843
# 2023-10-30 07:47:00+00:00  0.03125  0.034135  17.429460  17.639787
# 2023-10-30 07:48:00+00:00  0.03125  0.034047  17.432343  17.645888
#
#                            Tts_c_b_in     wmed_f    qmed_f    qmed_d  \
# time
# 2023-10-30 07:44:00+00:00   26.683404  35.328423  0.010750  0.000816
# 2023-10-30 07:45:00+00:00   26.681435  35.351805  0.010662  0.000818
# 2023-10-30 07:46:00+00:00   26.670880  35.418997  0.010647  0.000802
# 2023-10-30 07:47:00+00:00   26.663742  35.427615  0.010652  0.000808
# 2023-10-30 07:48:00+00:00   26.655250  35.422630  0.010637  0.000806
#
#                            Tmed_c_out  Tmed_c_in  ...   Thx_s_in  Thx_s_out  \
# time                                              ...
# 2023-10-30 07:44:00+00:00   16.069060       16.0  ...  15.296492  16.923871
# 2023-10-30 07:45:00+00:00   16.067952       16.0  ...  15.296910  16.952170
# 2023-10-30 07:46:00+00:00   16.031067       16.0  ...  15.296857  17.009618
# 2023-10-30 07:47:00+00:00   16.057810       16.0  ...  15.296970  17.080558
# 2023-10-30 07:48:00+00:00   16.035168       16.0  ...  15.297030  17.168850
#
#                               qhx_p  qhx_s   T3wv_src  T3wv_dis_in  \
# time
# 2023-10-30 07:44:00+00:00  0.000000    0.0  96.424700    17.662380
# 2023-10-30 07:45:00+00:00  0.000000    0.0  96.422570    17.660400
# 2023-10-30 07:46:00+00:00  1.387997    0.0  96.415720    17.649843
# 2023-10-30 07:47:00+00:00  1.577559    0.0  96.413525    17.639787
# 2023-10-30 07:48:00+00:00  1.576460    0.0  96.412153    17.645888
#
#                            T3wv_dis_out  q3wv_src  q3wv_dis  Jmed_e
# time
# 2023-10-30 07:44:00+00:00     26.683404  0.034011   0.03125     NaN
# 2023-10-30 07:45:00+00:00     26.681435  0.033959   0.03125     NaN
# 2023-10-30 07:46:00+00:00     26.670880  0.034200   0.03125     NaN
# 2023-10-30 07:47:00+00:00     26.663742  0.034135   0.03125     NaN
# 2023-10-30 07:48:00+00:00     26.655250  0.034047   0.03125     NaN
#
# [5 rows x 45 columns]

# %%
# Test model
from models_psa import SolarMED

# %autoreload 2

# Initialize model

model = SolarMED(
    sample_time=sample_rate_numeric,
    curve_fits_path='data/curve_fits.json',
    
    # Initial states. Thermal storage
    Tts_h=[df['Tts_h_t'].iloc[0], df['Tts_h_m'].iloc[0], df['Tts_h_b'].iloc[0]], 
    Tts_c=[df['Tts_c_t'].iloc[0], df['Tts_c_m'].iloc[0], df['Tts_c_b'].iloc[0]],
    Tsf_in=df['Tsf_in'].iloc[0],
    
    cost_w = cost_w, # €/m³ 
    cost_e = cost_e # €/kWhe
)
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Test model
# ----> 2 from models_psa import SolarMED
#       4 get_ipython().run_line_magic('autoreload', '2')
#       6 # Initialize model
#
# File ~/development_psa/models_psa/models_psa/__init__.py:77
#      73     SOLAR_FIELD_THERMAL_STORAGE_MED = 6  # Solar field providing heat to thermal storage, MED operation
#      74     THERMAL_STORAGE_MED = 7  # Solar field idle, thermal storage discharging, MED operation
# ---> 77 class SolarMED(BaseModel):
#      78     """
#      79     Model of a Multi-effect distillation pilot plant, static collectors solar field  and thermal storage system
#      80     located at Plataforma Solar de Almería.
#    (...)
#     105         - Alternatively, the model can be serialized to a JSON using the `solar_med.model_dump_json()` method.
#     106     """
#     108     # Limits
#     109     # Important to define first, so that they are available for validation
#     110     ## Flows. Need to be defined separately to validate using `within_range_or_zero_or_max`
#
# File ~/development_psa/models_psa/venv/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py:92, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#      90 config_wrapper = ConfigWrapper.for_model(bases, namespace, kwargs)
#      91 namespace['model_config'] = config_wrapper.config_dict
# ---> 92 private_attributes = inspect_namespace(
#      93     namespace, config_wrapper.ignored_types, class_vars, base_field_names
#      94 )
#      95 if private_attributes:
#      96     original_model_post_init = get_model_post_init(namespace, bases)
#
# File ~/development_psa/models_psa/venv/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py:380, in inspect_namespace(namespace, ignored_types, base_class_vars, base_class_fields)
#     374     raise PydanticUserError(
#     375         f'Field {var_name!r} defined on a base class was overridden by a non-annotated attribute. '
#     376         f'All field definitions, including overrides, require a type annotation.',
#     377         code='model-field-overridden',
#     378     )
#     379 elif isinstance(value, FieldInfo):
# --> 380     raise PydanticUserError(
#     381         f'Field {var_name!r} requires a type annotation', code='model-field-missing-annotation'
#     382     )
#     383 else:
#     384     raise PydanticUserError(
#     385         f'A non-annotated attribute was detected: `{var_name} = {value!r}`. All model fields require a '
#     386         f'type annotation; if `{var_name}` is not meant to be a field, you may be able to resolve this '
#     387         f"error by annotating it as a `ClassVar` or updating `model_config['ignored_types']`.",
#     388         code='model-field-missing-annotation',
#     389     )
#
# PydanticUserError: Field 'lims_T_hot' requires a type annotation
#
# For further information visit https://errors.pydantic.dev/2.6/u/model-field-missing-annotation
