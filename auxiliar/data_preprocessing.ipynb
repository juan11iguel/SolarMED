# %%
import numpy as np
import pandas as pd
from loguru import logger
from pathlib import Path
import hjson
import os

from phd_visualizations.utils.units import unit_conversion
from phd_visualizations.utils import rename_signal_ids_to_var_ids

# %%
data_path = Path(f'{os.getenv("HOME")}/Nextcloud/Juanmi_MED_PSA/EURECAT/data')

filename_process_data = '20230505_solarMED.csv'
filename_process_data2 = '20231030_MED.csv'

paths = [data_path / filename_process_data, data_path / filename_process_data2]
sample_rate_key: str = '60s'

# %%
# Load varibles configuration

with open( Path("../data") / "variables_config.hjson") as f:
    vars_config = hjson.load(f)

# %%
def process_dataframe(df: pd.DataFrame) -> pd.DataFrame:

    df = df.copy()

    df.index = df.index.round('s')
    df = df.tz_localize('UTC')
    if 'time.1' in df.columns:
        df.drop(columns='time.1', inplace=True)

    # Select columns of 'object' data type
    object_columns = df.select_dtypes(include=['object'])

    # Print the column names
    logger.debug(object_columns.columns)  # %%

    if not object_columns.empty:
        logger.warning(f"Columns with object data type that will be deleted: {object_columns.columns}")
        
    # Delete columns with 'object' data type
    df = df.select_dtypes(exclude=['object'])

    return df

# %%
index_cols = ['time', 'TimeStamp']

if not isinstance(paths, list):
    paths = [paths]

for path in paths:
    if isinstance(path, str):
        path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"Path {path} does not exist.")

# Read reference dataframe
df = None
for index_col in index_cols:
    try:
        df = pd.read_csv(paths[0], parse_dates=True, index_col=index_col)
        break
    except Exception as e:
        pass
        # logger.error(f'Error while reading data from {paths[0]} with index_col={index_col}: {e}')

if df is None:
    raise RuntimeError(f'Failed to read data from CSV file with any of the provided index columns: {index_cols}')

df = process_dataframe(df)
# Out:
# 2024-04-02 12:39:17.140 | DEBUG    | __main__:process_dataframe:14 - Index(['Date', 'Time'], dtype='object')
# 2024-04-02 12:39:17.142 | WARNING  | __main__:process_dataframe:17 - Columns with object data type that will be deleted: Index(['Date', 'Time'], dtype='object')

# %%
# Read additional dataframes and concatenate them
for idx, path in enumerate(paths[1:]):
    df_aux = None
    for index_col in index_cols:
        try:
            df_aux = pd.read_csv(path, parse_dates=True, index_col=index_col)
            df_aux.index.names = ['time']
            break
        except Exception as e:
            logger.error(f'Error while reading data from {path} with index_col={index_col}: {e}')

    if df_aux is None:
        logger.error(f'Failed to read data from CSV file with any of the provided index columns for the {idx+2} path: {index_cols}')

    df_aux = process_dataframe(df_aux)

    # Find the common columns in both dataframes and drop them from the second
    common_columns = df.columns.intersection(df_aux.columns)
    df_aux = df_aux.drop(columns=common_columns)
    df = pd.concat([df, df_aux], axis=1)

# Preprocessing
# Sample every `sample_rate` seconds to reduce the size of the dataframe
df = df.resample(sample_rate_key).mean()

# Rename columns from signal_id to var_id
df = rename_signal_ids_to_var_ids(df, vars_config)

# Convert units to model units
df = unit_conversion(df, vars_config, input_unit_key='units_scada', output_unit_key='units_model')

# Filter out nans until first value in Tts
logger.warning(f"Removing {df['Tts_h_t'].isna().sum()} NaNs from the dataframe")
df = df[df['Tts_h_t'].notna()]
# Out:
# 2024-04-02 12:39:23.706 | DEBUG    | __main__:process_dataframe:14 - Index([], dtype='object')
# 2024-04-02 12:39:23.871 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id RE-SF-001 not found in dataframe columns.
# 2024-04-02 12:39:23.872 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TE-DES-015 not found in dataframe columns.
# 2024-04-02 12:39:23.873 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id CT-DES-001 not found in dataframe columns.
# 2024-04-02 12:39:23.874 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-AQU-107a not found in dataframe columns.
# 2024-04-02 12:39:23.874 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id SW2TC1 not found in dataframe columns.
# 2024-04-02 12:39:23.875 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-DES-003 not found in dataframe columns.
# 2024-04-02 12:39:23.875 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-DES-005 not found in dataframe columns.
# 2024-04-02 12:39:23.913 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-AQU-107a not found in dataframe columns.
# 2024-04-02 12:39:23.926 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-SF-003 not found in dataframe columns.
# 2024-04-02 12:39:23.927 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-SF-005 not found in dataframe columns.
# 2024-04-02 12:39:23.928 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-SF-006 not found in dataframe columns.
# 2024-04-02 12:39:23.929 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-SF-007 not found in dataframe columns.
# 2024-04-02 12:39:23.930 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id FT-SF-008 not found in dataframe columns.
# 2024-04-02 12:39:23.930 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-018 not found in dataframe columns.
# 2024-04-02 12:39:23.931 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-019 not found in dataframe columns.
# 2024-04-02 12:39:23.932 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-024 not found in dataframe columns.
# 2024-04-02 12:39:23.932 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-025 not found in dataframe columns.
# 2024-04-02 12:39:23.933 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-030 not found in dataframe columns.
# 2024-04-02 12:39:23.934 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-031 not found in dataframe columns.
# 2024-04-02 12:39:23.934 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-036 not found in dataframe columns.
# 2024-04-02 12:39:23.935 | WARNING  | phd_visualizations.utils:rename_signal_ids_to_var_ids:55 - Signal id TT-SF-037 not found in dataframe columns.
# 2024-04-02 12:39:23.954 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tamb to C from C
# 2024-04-02 12:39:23.963 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tmed_s_out to C from C
# 2024-04-02 12:39:23.972 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_in to C from C
# 2024-04-02 12:39:23.981 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tsf_out to C from C
# 2024-04-02 12:39:23.990 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_in to C from C
# 2024-04-02 12:39:23.994 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_src_in to C from C
# 2024-04-02 12:39:24.000 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_out to C from C
# 2024-04-02 12:39:24.005 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis to C from C
# 2024-04-02 12:39:24.013 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_in to C from C
# 2024-04-02 12:39:24.021 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b_out to C from C
# 2024-04-02 12:39:24.025 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_dis_in to C from C
# 2024-04-02 12:39:24.032 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_t to C from C
# 2024-04-02 12:39:24.041 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_m to C from C
# 2024-04-02 12:39:24.049 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_h_b to C from C
# 2024-04-02 12:39:24.060 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_t to C from C
# 2024-04-02 12:39:24.068 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_m to C from C
# 2024-04-02 12:39:24.078 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Tts_c_b to C from C
# 2024-04-02 12:39:24.083 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_in to C from C
# 2024-04-02 12:39:24.087 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_p_out to C from C
# 2024-04-02 12:39:24.093 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_in to C from C
# 2024-04-02 12:39:24.098 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Thx_s_out to C from C
# 2024-04-02 12:39:24.104 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_src to C from C
# 2024-04-02 12:39:24.111 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated T3wv_dis_out to C from C
# 2024-04-02 12:39:24.113 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.155 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_s to m3h from Ls
# 2024-04-02 12:39:24.158 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pmed_c_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.160 | WARNING  | phd_visualizations.utils.units:unit_conversion:491 - Could not find any variable matching Tmed_c*_K in available variables. Using default value of 298.15 K
# 2024-04-02 12:39:24.165 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qmed_c to m3h from m3h
# 2024-04-02 12:39:24.170 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_d to kW from kW
# 2024-04-02 12:39:24.174 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_b to kW from kW
# 2024-04-02 12:39:24.183 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_c to kW from W
# 2024-04-02 12:39:24.189 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated Jmed_s_f to kW from W
# 2024-04-02 12:39:24.190 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Psf_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.246 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qsf to m3h from Lmin
# 2024-04-02 12:39:24.247 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.297 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_dis to m3h from Ls
# 2024-04-02 12:39:24.298 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Pts_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.333 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qts_src to m3h from Lmin
# 2024-04-02 12:39:24.335 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_p_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.387 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_p to m3h from Lmin
# 2024-04-02 12:39:24.389 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - Phx_s_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.442 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated qhx_s to m3h from Lmin
# 2024-04-02 12:39:24.444 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_src_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.470 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_src to m3h from Ls
# 2024-04-02 12:39:24.472 | WARNING  | phd_visualizations.utils.units:unit_conversion:480 - P3wv_dis_MPa not found in available variables. Using default value of 0.12 MPa
# 2024-04-02 12:39:24.503 | DEBUG    | phd_visualizations.utils.units:unit_conversion:552 - Updated q3wv_dis to m3h from Ls
# 2024-04-02 12:39:24.505 | WARNING  | __main__:<module>:33 - Removing 256434 NaNs from the dataframe

# %% [markdown]
# # Compare columns in two dataframes

# %%
df1 = pd.read_csv(data_path / '20231030_solarMED.csv', parse_dates=True, index_col='TimeStamp')
df2 = pd.read_csv(data_path / '20230505_solarMED.csv', parse_dates=True, index_col='TimeStamp')

# Find columns that are in df1 but not in df2
columns_df1_not_df2 = df1.columns.difference(df2.columns)

logger.info(f"Columns in df1 but not in df2: {columns_df1_not_df2}")
logger.info(f"Columns 1: {df1.columns}")
logger.info(f"Columns 2: {df2.columns}")
# Out:
# 2024-04-02 13:04:30.275 | INFO     | __main__:<module>:7 - Columns in df1 but not in df2: Index(['CT-DES-001', 'FT-DES-003', 'FT-DES-005', 'RE-SF-001', 'SW2TC1',
#        'TE-DES-015', 'TT-AQU-107a'],
#       dtype='object')
# 2024-04-02 13:04:30.276 | INFO     | __main__:<module>:8 - Columns 1: Index(['FT-AQU-100', 'FT-AQU-101', 'TT-AQU-106', 'TT-AQU-107a', 'TT-AQU-109',
#        'CT-DES-001', 'FT-DES-003', 'FT-DES-005', 'SW2TC1', 'TE-DES-015',
#        'TT-DES-030', 'FT-SF-001', 'FT-SF-002', 'RE-SF-001', 'TT-SF-001',
#        'TT-SF-002', 'TT-SF-003', 'TT-SF-004', 'TT-SF-005', 'TT-SF-006',
#        'TT-SF-007', 'TT-SF-008', 'TT-SF-009', 'TT-SF-010'],
#       dtype='object')
# 2024-04-02 13:04:30.277 | INFO     | __main__:<module>:9 - Columns 2: Index(['Row', 'Date', 'Time', 'FT-AQU-100_1', 'FT-AQU-101_1', 'SC-AQU-P102_1',
#        'TT-AQU-106_1', 'TT-AQU-109_1', 'ZT-AQU-TCV102_1', 'TT-DES-030_1',
#        'FT-SF-001_1', 'FT-SF-002_1', 'TT-SF-001_1', 'TT-SF-002_1',
#        'TT-SF-003_1', 'TT-SF-004_1', 'TT-SF-005_1', 'TT-SF-006_1',
#        'TT-SF-007_1', 'TT-SF-008_1', 'TT-SF-009_1', 'TT-SF-010_1',
#        'UK-SF-P001-fq_1', 'UK-SF-P002a-fq_1', 'FT-AQU-100', 'FT-AQU-101',
#        'SC-AQU-P102', 'TT-AQU-106', 'TT-AQU-109', 'ZT-AQU-TCV102',
#        'TT-DES-030', 'FT-SF-001', 'FT-SF-002', 'TT-SF-001', 'TT-SF-002',
#        'TT-SF-003', 'TT-SF-004', 'TT-SF-005', 'TT-SF-006', 'TT-SF-007',
#        'TT-SF-008', 'TT-SF-009', 'TT-SF-010', 'UK-SF-P001-fq',
#        'UK-SF-P002a-fq'],
#       dtype='object')

# %%
df3 = pd.read_csv(Path('../data/calibration') / '20230707_20230710_datos_tanques.csv', parse_dates=True, index_col='TimeStamp')

logger.info(list(df3.columns))
# Out:
# 2024-04-02 13:06:33.066 | INFO     | __main__:<module>:3 - ['TT-SF-004', 'TT-SF-005', 'TT-SF-006', 'TT-SF-001', 'TT-SF-002', 'TT-SF-003', 'TT-DES-030', 'FT-SF-001', 'FT-AQU-100', 'TT-SF-008', 'TT-AQU-109', 'FT-AQU-101', 'TT-AQU-106', 'TT-SF-007', 'ZT-AQU-TCV102']

# %% [markdown]
# # Nueva traza solarMED
# añadiendo datos necesarios para calibración de cada componente

# %%
traza_original = [
    'FT-AQU-100', 'FT-AQU-101', 'TT-AQU-106', 'TT-AQU-107a', 'TT-AQU-109',
    'CT-DES-001', 'FT-DES-003', 'FT-DES-005', 'SW2TC1', 'TE-DES-015',
    'TT-DES-030', 'FT-SF-001', 'FT-SF-002', 'RE-SF-001', 'TT-SF-001',
    'TT-SF-002', 'TT-SF-003', 'TT-SF-004', 'TT-SF-005', 'TT-SF-006',
    'TT-SF-007', 'TT-SF-008', 'TT-SF-009', 'TT-SF-010'
]

additional_signals = [
    'TT-SF-018', 'TT-SF-019', 'FT-SF-005', 'TT-SF-024', 'TT-SF-025',
    'FT-SF-006', 'TT-SF-030', 'TT-SF-031', 'FT-SF-007', 'TT-SF-036',
    'TT-SF-037', 'FT-SF-008',  'FT-SF-002', 'TT-SF-009', 'TT-SF-010',
     'TT-DES-030', 'RE-SF-001', 'TT-SF-010', 'TT-SF-009', 'TT-SF-007',
    'TT-SF-008', 'TT-DES-030', 'FT-SF-002', 'FT-SF-001', 'TT-SF-010', 
    'TT-SF-009', 'TT-SF-007', 'TT-SF-008', 'TT-DES-030', 'FT-SF-002',
    'FT-SF-001', 'TT-SF-010',  'TT-SF-009', 'TT-SF-007', 'TT-SF-008',
    'TT-DES-030', 'FT-SF-002', 'FT-SF-001', 'UK-SF-P001-fq'
]

# Convert lists to sets for easier comparison
first_set = set(traza_original)
second_set = set(additional_signals)

# Find the elements in the second set that are not in the first set
difference = second_set - first_set

# Print the elements that are not present in the first list
for element in difference:
    print(element)
# Out:
# FT-SF-005
# TT-SF-018
# FT-SF-007
# TT-SF-019
# FT-SF-006
# TT-SF-031
# TT-SF-036
# UK-SF-P001-fq
# TT-SF-025
# TT-SF-037
# FT-SF-008
# TT-SF-030
# TT-SF-024
